# %% [markdown]
# # Decision Tree Classifier Building in Scikit-learn

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Importing Required Libraries
#
# Let's first load the required libraries.

# %%
# Load libraries
import pandas as pd
import numpy as np
import itertools
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn import datasets #Import scikit-learn dataset library
from sklearn.tree import DecisionTreeClassifier # Import Decision Tree Classifier
from sklearn.model_selection import GridSearchCV # Import for hyperparameter tuning
from sklearn.model_selection import train_test_split # Import train_test_split function
from sklearn import metrics #Import scikit-learn metrics module for accuracy calculation
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ## Loading Data
# Let's first load the required Pima Indian Diabetes dataset using pandas' read CSV function. This time the data is imported through URL instead of last week where it was downloaded on Canvas

# %%
col_names = ['pregnant', 'glucose', 'bp', 'skin', 'insulin', 'bmi', 'pedigree', 'age', 'label']
# load dataset
url = "https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv"
# Read csv, using url as file
diabetes = pd.read_csv(url, header=None, names=col_names)
#Look at top rows to insure it worked
diabetes.head()
# Out:
#    pregnant  glucose  bp  skin  insulin   bmi  pedigree  age  label
# 0         6      148  72    35        0  33.6     0.627   50      1
# 1         1       85  66    29        0  26.6     0.351   31      0
# 2         8      183  64     0        0  23.3     0.672   32      1
# 3         1       89  66    23       94  28.1     0.167   21      0
# 4         0      137  40    35      168  43.1     2.288   33      1

# %% [markdown]
# ## Basic EDA and statistical analysis
#
# Let's start of with doing some basic EDA. This should be done every time you are opening a new data set. The only real steps for this is to look at the info to get information on nulls and to look at describe to get statistical information.

# %%
# Print dataset info
diabetes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   pregnant  768 non-null    int64
#  1   glucose   768 non-null    int64
#  2   bp        768 non-null    int64
#  3   skin      768 non-null    int64
#  4   insulin   768 non-null    int64
#  5   bmi       768 non-null    float64
#  6   pedigree  768 non-null    float64
#  7   age       768 non-null    int64
#  8   label     768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %% [markdown]
# The main things to note from this are
# 1. No Null values
# 2. All variables are numbers
#
# Now let's move on to the statistics

# %%
# Dataset Statistics. We dont need include='all' as all of our variables are numbers!
diabetes.describe().T
# Out:
#           count        mean         std     min       25%       50%  \
# pregnant  768.0    3.845052    3.369578   0.000   1.00000    3.0000
# glucose   768.0  120.894531   31.972618   0.000  99.00000  117.0000
# bp        768.0   69.105469   19.355807   0.000  62.00000   72.0000
# skin      768.0   20.536458   15.952218   0.000   0.00000   23.0000
# insulin   768.0   79.799479  115.244002   0.000   0.00000   30.5000
# bmi       768.0   31.992578    7.884160   0.000  27.30000   32.0000
# pedigree  768.0    0.471876    0.331329   0.078   0.24375    0.3725
# age       768.0   33.240885   11.760232  21.000  24.00000   29.0000
# label     768.0    0.348958    0.476951   0.000   0.00000    0.0000
#
#                 75%     max
# pregnant    6.00000   17.00
# glucose   140.25000  199.00
# bp         80.00000  122.00
# skin       32.00000   99.00
# insulin   127.25000  846.00
# bmi        36.60000   67.10
# pedigree    0.62625    2.42
# age        41.00000   81.00
# label       1.00000    1.00

# %% [markdown]
# The question creeping out of this summary is:
#
# *Can minimum value of below listed columns be zero (0)?*
#
# On these columns, a value of zero does not make sense and thus indicates missing value.
#
# Following columns or variables have an invalid zero value:
#
# * Glucose
# * BloodPressure
# * SkinThickness
# * Insulin
# * BMI

# %% [markdown]
# It is better to replace zeros with nan since after that counting them would be easier and zeros need to be replaced with suitable values. Since we are going to be heavily messing with the dataset let's make a copy so the original data isn't altered

# %%
# Create a deep copy of your dataset
diabetes_copy = diabetes.copy(deep = True)

# Replace the missing values
diabetes_copy[['glucose','bp','skin','insulin','bmi']] = diabetes_copy[['glucose','bp','skin','insulin','bmi']].replace(0,np.NaN)

# Check for missing values
print(diabetes_copy.isnull().sum())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 5
#       2 diabetes_copy = diabetes.copy(deep = True)
#       4 # Replace the missing values
# ----> 5 diabetes_copy[['glucose','bp','skin','insulin','bmi']] = diabetes_copy[['glucose','bp','skin','insulin','bmi']].replace(0,np.NaN)
#       7 # Check for missing values
#       8 print(diabetes_copy.isnull().sum())
#
# File ~\Documents\Masters Degree Classes\DBSA 6156 Machine Learning\DecisionTreesDiabetesDeterminant\venv\Lib\site-packages\numpy\__init__.py:413, in __getattr__(attr)
#     410     raise AttributeError(__former_attrs__[attr], name=None)
#     412 if attr in __expired_attributes__:
# --> 413     raise AttributeError(
#     414         f"`np.{attr}` was removed in the NumPy 2.0 release. "
#     415         f"{__expired_attributes__[attr]}",
#     416         name=None
#     417     )
#     419 if attr == "chararray":
#     420     warnings.warn(
#     421         "`np.chararray` is deprecated and will be removed from "
#     422         "the main namespace in the future. Use an array with a string "
#     423         "or bytes dtype instead.", DeprecationWarning, stacklevel=2)
#
# AttributeError: `np.NaN` was removed in the NumPy 2.0 release. Use `np.nan` instead.

# %% [markdown]
# For the sake of time let's fill all of the new null values with the median for the variable.
#
# **DON'T USE EASY FIXES LIKE THIS FOR PROJECT**

# %%
# Impute missing values with the median
diabetes_copy.fillna(diabetes_copy.median(), inplace=True)

# %% [markdown]
# ## Feature Selection
# Here, you need to divide given columns into two types of variables dependent (or target variable) and independent variable (or feature variables).
#
# A capital X is used for the dependant variables while a lowercase y is used for the dependant. There is no reason for this other than conventional use in industry

# %%
 #split dataset in features and target variable
feature_cols = ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']
# Features
X = diabetes_copy[feature_cols]
# Target variable
y = diabetes_copy.label

# %% [markdown]
# ## Splitting Data
#
# To understand model performance, dividing the dataset into a training set and a test set is a good strategy.
#
# Let's split the dataset by using function train_test_split(). You need to pass 3 parameters features, target, and test_set size.

# %%
# Split dataset into training set and test set, declare random state for repeatability
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1) # 70% training and 30% test

# %% [markdown]
# What does stratified do?

# %%
# y_train.value_counts()[0]

print('Train target split: ', str(y_train.value_counts()[1] / y_train.value_counts().sum()))
print('Test target split: ', str(y_test.value_counts()[1] / y_test.value_counts().sum()))
# Out:
# Train target split:  0.3407821229050279
# Test target split:  0.36796536796536794

# %% [markdown]
# ## Building Decision Tree Model [link](https://scikit-learn.org/stable/modules/generated/sklearn.tree.DecisionTreeClassifier.html)
#
# Let's create a Decision Tree Model using Scikit-learn. Many of the sklearn algorithms are implemented using the same standard steps:
#
# Step 1: Initiate the algorithm. Define the parameters (& hyperparameters of the algorithm) of the algorithm. For example, the maximum depth, the minimum samples in a leaf etc. (check documentation for more information)
#
# Step 2: Train the algorithm. Train the algorithm by fitting it to the X_train and y_train datasets.
#
# Step 3: Evaluating the algorithm. Evaluate the predictive power of the algorithm by comparing the predicted target values to the true values. We can do this for the training and testing dataset.

# %%
# Create Decision Tree classifer object
dt = DecisionTreeClassifier(random_state = 42)

# Train Decision Tree Classifer
dt = dt.fit(X_train,y_train)

# Predict the response for test and train dataset
y_pred = dt.predict(X_test)
y_pred_train = dt.predict(X_train)
# Model Accuracy, how often is the classifier correct?
print("Accuracy Test:",metrics.accuracy_score(y_test, y_pred))
# Check the accuracy for train
print("Accuracy Train:",metrics.accuracy_score(y_train, y_pred_train))
# Out:
# Accuracy Test: 0.6883116883116883
# Accuracy Train: 1.0

# %% [markdown]
# A training accuracy of 1.0 means that the decision tree has perfectly memorized the training data. Every instance in the training set is correctly predicted by the fully grown tree.
# The test accuracy is significantly lower (0.7229), indicating that the model does not generalize well to new, unseen data. The high training accuracy does not translate to good performance on data the model hasn't seen during training.

# %% [markdown]
# **Evaluation**

# %%
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
cm=confusion_matrix(y_test,y_pred)
print(cm) # row: true labels, cols: predicted labels
f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the metrics
print("F1 Score: ", np.round(f1,3))
print("Accuracy: ", np.round(accuracy,3))
print("Precision:", np.round(precision,3))
print("Recall:   ", np.round(recall,3))
tree_auc = roc_auc_score(y_test, dt.predict_proba(X_test)[:,1])
print("ROC AUC:", np.round(tree_auc,3))
# Out:
# [[117  29]
#  [ 43  42]]
# F1 Score:  0.538
# Accuracy:  0.688
# Precision: 0.592
# Recall:    0.494
# ROC AUC: 0.648

# %% [markdown]
# **Visualizing Decision the fully grown Trees**
#
# You can use Scikit-learn's export_graphviz function for display the tree within a Jupyter notebook.

# %%
#Import some additional libraries
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image
import pydotplus

# Plot the decision tree
dot_data = StringIO()
export_graphviz(dt, out_file=dot_data,
                filled=True, rounded=True,
                special_characters=True,feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('diabetes.png')
Image(graph.create_png())
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[14], line 5
#       3 from six import StringIO
#       4 from IPython.display import Image
# ----> 5 import pydotplus
#       7 # Plot the decision tree
#       8 dot_data = StringIO()
#
# ModuleNotFoundError: No module named 'pydotplus'

# %% [markdown]
# What's your first reaction when seeing this? Probably something along the lines of "I can't read this!"
#
# This is due to the tree being unpruned. This unpruned tree is unexplainable, overfits, and not easy to understand. In the next section, let's optimize it by pruning.

# %% [markdown]
# ## How can we enhance the generalization capability and interpretability of a Decision Tree?

# %% [markdown]
# **Answer: Tree Pruning**

# %% [markdown]
# In Scikit-learn, optimization of decision tree classifier is performed by only pre-pruning. Maximum depth of the tree can be used as a control variable for pre-pruning. In the following the example, you can plot a decision tree on the same data with max_depth=3. Here is a list of other pre-pruning parameters:
#
# **criterion : optional (default=”gini”) or Choose attribute selection measure:** This parameter allows us to use the different-different attribute selection measure. Supported criteria are “gini” for the Gini index and “entropy” for the information gain.
#
#
# **max_depth : int or None, optional (default=None) or Maximum Depth of a Tree:** The maximum depth of the tree. If None, then nodes are expanded until all the leaves contain less than min_samples_split samples. The higher value of maximum depth causes overfitting, and a lower value causes underfitting.

# %%
# Create Decision Tree classifer object use a different name here. This allows for previous model to be called upon if were to need it.
#Set the hyperparamaneter max_depth=3 and see how the test and train accuracy changes.

dt2 = DecisionTreeClassifier(criterion="entropy", max_depth=3, random_state = 1)

# Train Decision Tree Classifer
dt2 = dt2.fit(X_train,y_train)

y_pred = dt2.predict(X_test)
y_pred_train = dt2.predict(X_train)
# Model Accuracy, how often is the classifier correct?
print("Accuracy Test:",metrics.accuracy_score(y_test, y_pred))
# Model Accuracy, how often is the classifier correct?
print("Accuracy Train:",metrics.accuracy_score(y_train, y_pred_train))
# Out:
# Accuracy Test: 0.7662337662337663
# Accuracy Train: 0.7635009310986964

# %% [markdown]
# Well, the classification rate increased, which is better accuracy than the previous model and it is generalizing better.

# %%
# Plot the decision tree (copy from prior code switching out dt for dt2)
dot_data = StringIO()
export_graphviz(dt2, out_file=dot_data,
                filled=True, rounded=True,
                special_characters=True, feature_names = feature_cols,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png('diabetes.png')
Image(graph.create_png())

# %% [markdown]
# This pruned model is less complex, explainable, and easy to understand than the previous decision tree model plot. In addition, it should generalize better.

# %% [markdown]
# # How to find the best values of hyperparameters? Grid Search

# %% [markdown]
# Instead of doing hyperparameter tuning manually, the GridSearchCV function from the sklearn.model_selection library is used to perform an automated grid search for hyperparameter tuning in the Decision Tree model. The param_grid argument defines the hyperparameters to be tuned and the values to be tried. The cv argument sets the number of folds for cross-validation. The fit function is used to fit the model to the data, and the best_params_ and best_score_ attributes are used to get the best hyperparameters and best score, respectively.
#
# The Decision Tree model is defined with the DecisionTreeClassifier class from the sklearn.tree library, and the hyperparameters to be tuned are max_depth, min_samples_split, and min_samples_leaf. The values to be tried for each hyperparameter are specified in the param_grid dictionary. The grid search performs a 10-fold cross-validation, and the best hyperparameters and best score are printed.

# %%
# Define the Decision Tree model
model = DecisionTreeClassifier(random_state = 42)

# Define the hyperparameters to be tuned
param_grid = {'criterion': ['entropy','gini'],
              'max_depth': [2, 3, 4 ],
              'min_samples_split': [2, 3, 4, 5, 6, 7],
              'min_samples_leaf': [1, 2, 3, 4, 5, 6, 7]}

# Perform grid search
grid = GridSearchCV(model, param_grid, cv=5)
grid.fit(X_train, y_train)

# Print the best parameters and best score
print("Best parameters:", grid.best_params_) #best model params
print("Best score:", grid.best_score_) #mean CV score of best model

# Extract best model and evaluate it on test set
best_model = grid.best_estimator_ #best model
print("Accuracy of best decision tree: ", best_model.score(X_test, y_test))
# Out:
# Best parameters: {'criterion': 'entropy', 'max_depth': 3, 'min_samples_leaf': 1, 'min_samples_split': 2}
# Best score: 0.7355140186915887
# Accuracy of best decision tree:  0.7662337662337663
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,

# %% [markdown]
# Automated hyperparameter search identified best params (in agreement with what we found earlier), without manual trial and error.

# %% [markdown]
# ### Pros
# * Decision trees are easy to interpret and visualize.
# * It can easily capture Non-linear patterns.
# * It requires fewer data preprocessing from the user, for example, there is no need to normalize columns.
# * It can be used for feature engineering such as predicting missing values, suitable for variable selection.
# * The decision tree has no assumptions about distribution because of the non-parametric nature of the algorithm.
#
# ### Cons
# * Sensitive to noisy data. It can overfit noisy data.
# * The small variation(or variance) in data can result in the different decision tree. This can be reduced by bagging and boosting algorithms.
# * Decision trees are biased with imbalance dataset, so it is recommended that balance out the dataset before creating the decision tree.

# %% [markdown]
# ## Random Forest Classifier [Link](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestClassifier.html)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# You will be building a model on the diabetes data again! No need to rexplore data as we already did that!

# %% [markdown]
# After splitting, you will train the model on the training set and perform predictions on the test set.

# %%
#Import Random Forest Function
from sklearn.ensemble import RandomForestClassifier

# Create a Random Forest Classifier
rf=RandomForestClassifier(n_estimators=10, random_state=1)
#n_estimators: Number of trees in the forest

# Train the model using the training set
rf.fit(X_train,y_train)

# Predict obs in test set
y_pred_rf=rf.predict(X_test)
y_pred_train_rf=rf.predict(X_train)

# %% [markdown]
# After training, check the accuracy using actual and predicted values.

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy Test:",metrics.accuracy_score(y_test, y_pred_rf))
# Check the accuracy for train
print("Accuracy Train:",metrics.accuracy_score(y_train, y_pred_train_rf))
# Out:
# Accuracy Test: 0.7792207792207793
# Accuracy Train: 0.9813780260707635

# %% [markdown]
# Model is clearly overfit. We need to set the hyperparameters.
#
# n_estimator,max_features,max_depth,bootstrap etc.

# %%
#Hyperparameter Tuning.
rfc=RandomForestClassifier(random_state=42)
param_grid = {
    'n_estimators': [1, 5, 10, 20, 50, 100, 150, 200, 300],
    'max_features': ['sqrt', 'log2'],
    'max_depth' : [2,3]
}
CV_rfc = GridSearchCV(estimator=rfc, param_grid=param_grid, cv= 4)
CV_rfc.fit(X_train, y_train)
CV_rfc.best_params_
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/ma/core.py:2820: RuntimeWarning: invalid value encountered in cast
#   _data = np.array(data, dtype=dtype, copy=copy,
# {'max_depth': 3, 'max_features': 'sqrt', 'n_estimators': 200}

# %%
# Create a Random Forest Classifier
rf1=RandomForestClassifier(n_estimators=200, max_depth=3 ,max_features='sqrt',random_state=42)
#n_estimators: Number of trees in the forest

# Train the model using the training set
rf1.fit(X_train,y_train)

# Predict obs in test set
y_pred_rf1=rf1.predict(X_test)
y_pred_train_rf1=rf1.predict(X_train)
# Model Accuracy, how often is the classifier correct?
print("Accuracy Test:",metrics.accuracy_score(y_test, y_pred_rf1))
# Model Accuracy, how often is the classifier correct?
print("Accuracy Train:",metrics.accuracy_score(y_train, y_pred_train_rf1))
# Out:
# Accuracy Test: 0.7792207792207793
# Accuracy Train: 0.7839851024208566

# %%
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
cm=confusion_matrix(y_test,y_pred_rf1)
print(cm)
f1 = f1_score(y_test, y_pred_rf1)
accuracy = accuracy_score(y_test, y_pred_rf1)
precision = precision_score(y_test, y_pred_rf1)
recall = recall_score(y_test, y_pred_rf1)

# Print the metrics
print("F1 Score: ", np.round(f1,3))
print("Accuracy: ", np.round(accuracy,3))
print("Precision:", np.round(precision,3))
print("Recall:   ", np.round(recall,3))
tree_auc = roc_auc_score(y_test, rf1.predict_proba(X_test)[:,1])
print("ROC AUC:", np.round(tree_auc,3))
# Out:
# [[134  12]
#  [ 39  46]]
# F1 Score:  0.643
# Accuracy:  0.779
# Precision: 0.793
# Recall:    0.541
# ROC AUC: 0.883

# %%
num_estimators_list = [5,10,15,20,25,40, 50, 100, 200,250,300,350,400,450,500]

# Initialize lists to store results
accuracy_results = []

# Iterate over different values of n_estimators
for num_estimators in num_estimators_list:
    # Create a Random Forest classifier
    rf_classifier = RandomForestClassifier(n_estimators=num_estimators,max_features='sqrt',random_state=42)

    # Fit the classifier to the training data
    rf_classifier.fit(X_train, y_train)

    # Make predictions on the test data
    y_pred = rf_classifier.predict(X_test)

    # Calculate accuracy and store in the list
    accuracy = accuracy_score(y_test, y_pred)
    accuracy_results.append(accuracy)

# Plotting
plt.figure(figsize=(8, 6))
plt.plot(num_estimators_list, accuracy_results, marker='o')
plt.xlabel('Number of Estimators')
plt.ylabel('Accuracy')
plt.title('Impact of Number of Estimators on Accuracy')
plt.grid(True)
plt.show()

# %% [markdown]
# **Check the individual Trees** in RF

# %%
#Plot individual trees in random forest.


num_trees_to_plot = 3

for i in range(num_trees_to_plot):
    # Plot individual trees and save as PNG
    dot_data = StringIO()
    export_graphviz(rf1.estimators_[i], out_file=dot_data,
                  filled=True, rounded=True,
                   special_characters=True, feature_names = feature_cols,class_names=['0','1'])

    graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
    graph.write_png(f'diabetes_tree_{i+1}.png')
    print(f'Tree {i}')
    # Display the plot
    display(Image(graph.create_png()))
# Out:
# Tree 0
# Tree 1
# Tree 2

# %% [markdown]
# Tree 0 Uses Glucose, bmi, pregnant and bp
#
# Tree 1 uses insulin, bp, bmi, pregnant , age
#
# **Random selection of both variables (features) and the creation of individual trees. This randomness is a key aspect of the algorithm and contributes to the overall effectiveness of Random Forests.**

# %% [markdown]
# You can also make a prediction for a single item, for example:
#
# * pregnant = 0
# * glucose = 115
# * bp = 81
# * insulin = 133
# * bmi = 33
# * pedigree = 0.3
# * age = 31
#
# Now you can predict which type of flower it is.
# Below is the order of the variables from the split earlier in the lab
#
# ['pregnant', 'insulin', 'bmi', 'age','glucose','bp','pedigree']

# %%
print(rf1.predict([[0, 133, 33, 31, 115, 81, 0.3]]))
# Out:
# [0]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but RandomForestClassifier was fitted with feature names
#   warnings.warn(

# %% [markdown]
# Here, 0 indicates not diabetic

# %% [markdown]
# ## Finding Important Features in Scikit-learn
#
# Here, you are finding important features or selecting features in the diabetes dataset. In scikit-learn, you can perform this task in the following steps:
#
# * First, you need to create a random forests model.
# * Second, use the feature importance variable to see feature importance scores.
# * Third, visualize these scores using the seaborn library.

# %% [markdown]
# **The feature importance in Random Forest is calculated based on how much each feature contributes to reducing impurity or error in the decision trees. Features that are frequently used for splitting nodes across multiple trees and lead to more significant reductions in impurity are considered more important.**

# %%
#Look at feature importance
feature_imp = pd.Series(rf1.feature_importances_,index=feature_cols).sort_values(ascending=False)
#Display feature importance
feature_imp
# Out:
# glucose     0.347186
# bmi         0.208967
# insulin     0.141276
# age         0.131995
# pedigree    0.076559
# pregnant    0.068870
# bp          0.025148
# dtype: float64

# %% [markdown]
# You can also visualize the feature importance. Visualizations are easy to understand and interpretable.
#
# For visualization, you can use a combination of matplotlib and seaborn. Because seaborn is built on top of matplotlib, it offers a number of customized themes and provides additional plot types. Matplotlib is a superset of seaborn and both are equally important for good visualizations.

# %%
# %matplotlib inline
# Creating a bar plot
sns.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# Feature importance helps in selecting the most relevant features for a predictive model. By identifying and focusing on the most important features, you can simplify your model and potentially improve its interpretability.
# Feature importance in a Random Forest model provides a means to simplify the model and enhance interpretability.
# For instance, variables with importance values below a certain threshold, such as <0.1, can be considered less influential and potentially removed. In scenarios where the model is intricate and involves a large number of variables, feature selection based on importance scores becomes a valuable strategy to reduce complexity and improve model understanding.

# %% [markdown]
# # Adaboost classifier
#
# ![image.png](data:image/png;base64,...)
#
# ## Importing Required Libraries
# Let's first load the required libraries.

# %%
# Load library
from sklearn.ensemble import AdaBoostClassifier

# %% [markdown]
# ## Building the AdaBoost Model
#
# Let's create the AdaBoost Model using Scikit-learn. AdaBoost uses Decision Tree Classifier as default Classifier.

# %%
# Create adaboost classifer object
abc = AdaBoostClassifier(n_estimators=10, algorithm='SAMME',
                         learning_rate=1, random_state=1)
# Train Adaboost Classifer
model = abc.fit(X_train, y_train)

#Predict the response for test dataset
y_pred = model.predict(X_test)

# %% [markdown]
# "The most important parameters are base_estimator, n_estimators, and learning_rate." (Adaboost Classifier, Chris Albon)
#
# + **base_estimator:** It is a weak learner used to train the model. It uses DecisionTreeClassifier as default weak learner for training purpose. You can also specify different machine learning algorithms.
# + **n_estimators:** Number of weak learners to train iteratively.
# + **learning_rate:** It contributes to the weights of weak learners. It uses 1 as a default value.

# %% [markdown]
# ## Evaluate Model
#
# Let's estimate, how accurately the classifier or model can predict the type of cultivars.
#
# Accuracy can be computed by comparing actual test set values and predicted values.

# %%
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.7619047619047619

# %%
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
cm=confusion_matrix(y_test,y_pred)
print(cm)
f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the metrics
print("F1 Score: ", np.round(f1,3))
print("Accuracy: ", np.round(accuracy,3))
print("Precision:", np.round(precision,3))
print("Recall:   ", np.round(recall,3))
tree_auc = roc_auc_score(y_test, model.predict_proba(X_test)[:,1])
print("ROC AUC:", np.round(tree_auc,3))
# Out:
# [[126  20]
#  [ 35  50]]
# F1 Score:  0.645
# Accuracy:  0.762
# Precision: 0.714
# Recall:    0.588
# ROC AUC: 0.838

# %%
# explore model attributes

print('\nBase Estimator')
display(abc.estimator_)
print('\nEstimators')
display(abc.estimators_)
print('\nEstimator Weights')
display(abc.estimator_weights_)
print('\nEstimator Errors')
display(abc.estimator_errors_)
print('\nFeature Importance')
display(abc.feature_importances_)
# Out:
# Base Estimator
# DecisionTreeClassifier(max_depth=1)
# Estimators
# [DecisionTreeClassifier(max_depth=1, random_state=1791095845),
#  DecisionTreeClassifier(max_depth=1, random_state=2135392491),
#  DecisionTreeClassifier(max_depth=1, random_state=946286476),
#  DecisionTreeClassifier(max_depth=1, random_state=1857819720),
#  DecisionTreeClassifier(max_depth=1, random_state=491263),
#  DecisionTreeClassifier(max_depth=1, random_state=550290313),
#  DecisionTreeClassifier(max_depth=1, random_state=1298508491),
#  DecisionTreeClassifier(max_depth=1, random_state=2143362693),
#  DecisionTreeClassifier(max_depth=1, random_state=630311759),
#  DecisionTreeClassifier(max_depth=1, random_state=1013994432)]
# Estimator Weights
# array([0.9945281 , 0.42967883, 0.52121741, 0.37635131, 0.47067781,
#        0.25467901, 0.3736009 , 0.45462644, 0.25456528, 0.39079634])
# Estimator Errors
# array([0.27001862, 0.39420303, 0.37256761, 0.40700722, 0.38445583,
#        0.43667217, 0.4076712 , 0.38826135, 0.43670015, 0.40352561])
# Feature Importance
# array([0.08644557, 0.        , 0.3493195 , 0.18736592, 0.27630399,
#        0.        , 0.10056502])

# %%
# explore prediction outputs

model_predictions = np.zeros(shape=(1,10))

i = 0
for estimator in model.estimators_:
    #print(estimator.predict(X_test.iloc[0:1,:]))
    model_predictions[0][i] = estimator.predict(X_test.iloc[0:1,:])#0 vs 1
    i+=1

print("\nEnsemble Prediction")
print(model.predict(X_test.iloc[0:1,:]))

print("\nEstimator Prediction")
print(model_predictions)

print("\nEstimator Weights")
print(abc.estimator_weights_)
# Out:
# Ensemble Prediction
# [1]
#
# Estimator Prediction
# [[1. 0. 0. 0. 1. 0. 0. 1. 1. 1.]]
#
# Estimator Weights
# [0.9945281  0.42967883 0.52121741 0.37635131 0.47067781 0.25467901
#  0.3736009  0.45462644 0.25456528 0.39079634]
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# <ipython-input-36-d4568012bb84>:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   model_predictions[0][i] = estimator.predict(X_test.iloc[0:1,:])#0 vs 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# <ipython-input-36-d4568012bb84>:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   model_predictions[0][i] = estimator.predict(X_test.iloc[0:1,:])#0 vs 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# <ipython-input-36-d4568012bb84>:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   model_predictions[0][i] = estimator.predict(X_test.iloc[0:1,:])#0 vs 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# <ipython-input-36-d4568012bb84>:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   model_predictions[0][i] = estimator.predict(X_test.iloc[0:1,:])#0 vs 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# <ipython-input-36-d4568012bb84>:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   model_predictions[0][i] = estimator.predict(X_test.iloc[0:1,:])#0 vs 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# <ipython-input-36-d4568012bb84>:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   model_predictions[0][i] = estimator.predict(X_test.iloc[0:1,:])#0 vs 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# <ipython-input-36-d4568012bb84>:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   model_predictions[0][i] = estimator.predict(X_test.iloc[0:1,:])#0 vs 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# <ipython-input-36-d4568012bb84>:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   model_predictions[0][i] = estimator.predict(X_test.iloc[0:1,:])#0 vs 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# <ipython-input-36-d4568012bb84>:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   model_predictions[0][i] = estimator.predict(X_test.iloc[0:1,:])#0 vs 1
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:486: UserWarning: X has feature names, but DecisionTreeClassifier was fitted without feature names
#   warnings.warn(
# <ipython-input-36-d4568012bb84>:8: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   model_predictions[0][i] = estimator.predict(X_test.iloc[0:1,:])#0 vs 1

# %% [markdown]
# For further evaluation, you can also create a model using different Base Estimators (can do a gridsearch to find best hyperparameters).

# %% [markdown]
# **Pros**
#
# AdaBoost is easy to implement. It iteratively corrects the mistakes of the weak classifier and improves accuracy by combining weak learners. You can use many base classifiers with AdaBoost. AdaBoost is not prone to overfitting. This can be found out via experiment results, but there is no concrete reason available.
#
# **Cons**
#
# AdaBoost is sensitive to noise data. It is highly affected by outliers because it tries to fit each point perfectly. AdaBoost is slower compared to XGBoost.

# %% [markdown]
# #XG Boost
#
# XGBoost, or eXtreme Gradient Boosting, is a powerful gradient boosting algorithm known for speed, scalability, and high performance. **The training process in XGBoost involves the sequential construction of decision trees, each aimed at minimizing the overall loss function.**
# It incorporates regularization, tree pruning, and feature importance, handles missing values, supports parallel computing, and is widely adopted in competitions. Its versatility makes it a popular choice for regression and classification tasks.

# %%
import xgboost as xgb
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

model = xgb.XGBClassifier(max_depth=12,
                        subsample=0.33,
                        objective='binary:logistic',
                        n_estimators=500,
                        learning_rate = 0.1,
                        eval_metric=["error", "logloss"])
eval_set = [(X_train, y_train), (X_test, y_test)]
model.fit(X_train, y_train.values.ravel(), eval_set=eval_set, verbose=False)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=['error', 'logloss'],
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=12,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=500,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# XGBoost's hyperparameters read all about them here.  The most common ones that you should know are:
#
# 1.learning_rate: step size shrinkage used to prevent overfitting. Range is [0,1]
#
# 2.max_depth: determines how deeply each tree is allowed to grow during any boosting round.
#
# 3.subsample: percentage of samples used per tree. Low value can lead to underfitting.
#
# 4.colsample_bytree: percentage of features used per tree. High value can lead to overfitting.
#
# 5.n_estimators: number of trees you want to build.
# objective: determines the loss function to be used like reg:linear for regression problems, reg:logistic for classification problems with only decision, binary:logistic for classification problems with probability. XGBoost also supports regularization parameters to penalize models as they become more complex and reduce them to simple (parsimonious) models.
#
# 6.gamma: controls whether a given node will split based on the expected reduction in loss after the split (minimum loss reduction required to further partition). A higher value leads to fewer splits. Supported only for tree-based learners.
#
# 7.alpha: L1 regularization on leaf weights. A large value leads to more regularization.
#
# 8.lambda: L2 regularization on leaf weights and is smoother than L1 regularization.
#
# It's also worth mentioning that though you are using trees as your base learners, you can also use XGBoost's relatively less popular linear base learners and one other tree learner known as dart. All you have to do is set the booster parameter to either gbtree (default), gblinear or dart.

# %% [markdown]
# Now, Let's see how the classification error changes with added rounds of boosted tree.

# %%
from matplotlib import pyplot
# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# evaluate predictions
accuracy = accuracy_score(y_test, predictions)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# retrieve performance metrics
results = model.evals_result()
epochs = len(results['validation_0']['error'])
x_axis = range(0, epochs)
# plot log loss
fig, ax = pyplot.subplots()
ax.plot(x_axis, results['validation_0']['logloss'], label='Train')
ax.plot(x_axis, results['validation_1']['logloss'], label='Test')
ax.legend()
pyplot.ylabel('Log Loss')
pyplot.title('XGBoost Log Loss')
pyplot.show()
# plot classification error
fig, ax = pyplot.subplots()
ax.plot(x_axis, results['validation_0']['error'], label='Train')
ax.plot(x_axis, results['validation_1']['error'], label='Test')
ax.legend()
pyplot.ylabel('Classification Error')
pyplot.title('XGBoost Classification Error')
pyplot.show()
# Out:
# Accuracy: 77.06%

# %% [markdown]
# The classification error plot distinctly demonstrates a consistent decrease with each boosting iteration for both the training set. However, there is clearly overfitting happening as the number of rounds goes higher.

# %% [markdown]
# **Let's Experiment**

# %% [markdown]
# **Set an Early stopping rate to 20**

# %%
import xgboost as xgb
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

model = xgb.XGBClassifier(max_depth=12,
                        subsample=0.33,
                        objective='binary:logistic',
                        n_estimators=300,
                        learning_rate = 0.1,
                        eval_metric=["error", "logloss"],
                        early_stopping_rounds=20)
eval_set = [(X_train, y_train), (X_test, y_test)]
model.fit(X_train, y_train.values.ravel(), eval_set=eval_set, verbose=False)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=20,
#               enable_categorical=False, eval_metric=['error', 'logloss'],
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=12,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=300,
#               n_jobs=None, num_parallel_tree=None, random_state=None, ...)

# %%
from matplotlib import pyplot
# make predictions for test data
y_pred = model.predict(X_test)
predictions = [round(value) for value in y_pred]

# evaluate predictions
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy: %.2f%%" % (accuracy * 100.0))
# retrieve performance metrics
results = model.evals_result()
epochs = len(results['validation_0']['error'])
x_axis = range(0, epochs)
# plot log loss
fig, ax = pyplot.subplots()
ax.plot(x_axis, results['validation_0']['logloss'], label='Train')
ax.plot(x_axis, results['validation_1']['logloss'], label='Test')
ax.legend()
pyplot.ylabel('Log Loss')
pyplot.title('XGBoost Log Loss')
pyplot.show()
# plot classification error
fig, ax = pyplot.subplots()
ax.plot(x_axis, results['validation_0']['error'], label='Train')
ax.plot(x_axis, results['validation_1']['error'], label='Test')
ax.legend()
pyplot.ylabel('Classification Error')
pyplot.title('XGBoost Classification Error')
pyplot.show()
# Out:
# Accuracy: 77.49%

# %% [markdown]
# The accuracy has improved from 76% to 80% and we have reduced overfitting by introducing early stopping to the boosting cycles.

# %%
import xgboost as xgb
import numpy as np


#Converting the data to DMatrix
data = xgb.DMatrix(X, label=y)

#Hyperparameters
params = {
    'objective': 'binary:logistic',
    'max_depth': 3,
    'learning_rate': 0.1,
}

#Performing cross-validation
cv_results = xgb.cv(params, data, num_boost_round=50, nfold=3,metrics='error', seed=42)

#Printing the results
print(cv_results.tail())

fig, ax = pyplot.subplots()
ax.plot(cv_results['train-error-mean'],label='Train')
ax.plot(cv_results['test-error-mean'], label='Test')
ax.legend()
pyplot.ylabel('Classification Error')
pyplot.title('XGBoost Classification Error')
pyplot.show()
# Out:
#     train-error-mean  train-error-std  test-error-mean  test-error-std
# 45          0.135417         0.003320         0.244792        0.007366
# 46          0.136719         0.003189         0.242188        0.005524
# 47          0.136068         0.001841         0.240885        0.004872
# 48          0.134115         0.002436         0.247396        0.001841
# 49          0.134766         0.002762         0.243490        0.001841

# %% [markdown]
# **Hyper Parameter  Tuning**

# %%
from sklearn.model_selection import train_test_split, GridSearchCV, RandomizedSearchCV
params = {'learning_rate': [0.1, 0.25, 0.4],
          'max_depth': [5,10,12],
          'subsample': [0.2,0.3,0.5, 0.7],
          'n_estimators': [5,10,15,20,25,30,35,40,50,150,300]}


random_search = RandomizedSearchCV(model, param_distributions=params, n_iter=10, cv=5, n_jobs=1, verbose=1,random_state=42)
random_search.fit(X_train, y_train, eval_set=[(X_test, y_test)]) #typically, should have a validation set in eval_set, different from the training and testing data.
                                                                 #For this notebook we are using test set since the dataset is small.
print("test_score - " + str(random_search .score(X_test, y_test)))
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [0]	validation_0-error:0.36797	validation_0-logloss:0.62579
# [1]	validation_0-error:0.36797	validation_0-logloss:0.59978
# [2]	validation_0-error:0.36797	validation_0-logloss:0.57986
# [3]	validation_0-error:0.35498	validation_0-logloss:0.56175
# [4]	validation_0-error:0.26840	validation_0-logloss:0.53954
# [5]	validation_0-error:0.25974	validation_0-logloss:0.52536
# [6]	validation_0-error:0.25541	validation_0-logloss:0.51819
# [7]	validation_0-error:0.23377	validation_0-logloss:0.50695
# [8]	validation_0-error:0.23810	validation_0-logloss:0.49958
# [9]	validation_0-error:0.23377	validation_0-logloss:0.48968
# [10]	validation_0-error:0.21645	validation_0-logloss:0.48489
# [11]	validation_0-error:0.21212	validation_0-logloss:0.47573
# [12]	validation_0-error:0.20779	validation_0-logloss:0.47027
# [13]	validation_0-error:0.21212	validation_0-logloss:0.46625
# [14]	validation_0-error:0.19481	validation_0-logloss:0.46491
# [15]	validation_0-error:0.20779	validation_0-logloss:0.45970
# [16]	validation_0-error:0.20346	validation_0-logloss:0.45517
# [17]	validation_0-error:0.20779	validation_0-logloss:0.45300
# [18]	validation_0-error:0.20779	validation_0-logloss:0.45234
# [19]	validation_0-error:0.20779	validation_0-logloss:0.44731
# [20]	validation_0-error:0.20779	validation_0-logloss:0.44549
# [21]	validation_0-error:0.20346	validation_0-logloss:0.44311
# [22]	validation_0-error:0.20346	validation_0-logloss:0.44149
# [23]	validation_0-error:0.20346	validation_0-logloss:0.43692
# [24]	validation_0-error:0.19913	validation_0-logloss:0.43441
# [25]	validation_0-error:0.19481	validation_0-logloss:0.43285
# [26]	validation_0-error:0.20346	validation_0-logloss:0.43296
# [27]	validation_0-error:0.18615	validation_0-logloss:0.42992
# [28]	validation_0-error:0.18182	validation_0-logloss:0.42832
# [29]	validation_0-error:0.18615	validation_0-logloss:0.42736
# [30]	validation_0-error:0.18615	validation_0-logloss:0.42895
# [31]	validation_0-error:0.19048	validation_0-logloss:0.42855
# [32]	validation_0-error:0.18182	validation_0-logloss:0.43160
# [33]	validation_0-error:0.18182	validation_0-logloss:0.43165
# [34]	validation_0-error:0.19913	validation_0-logloss:0.43522
# [35]	validation_0-error:0.19481	validation_0-logloss:0.43539
# [36]	validation_0-error:0.19913	validation_0-logloss:0.43906
# [37]	validation_0-error:0.21212	validation_0-logloss:0.44078
# [38]	validation_0-error:0.19913	validation_0-logloss:0.44119
# [39]	validation_0-error:0.19048	validation_0-logloss:0.43995
# [40]	validation_0-error:0.19481	validation_0-logloss:0.44156
# [41]	validation_0-error:0.19481	validation_0-logloss:0.44212
# [42]	validation_0-error:0.19048	validation_0-logloss:0.44044
# [43]	validation_0-error:0.19048	validation_0-logloss:0.43947
# [44]	validation_0-error:0.18615	validation_0-logloss:0.44161
# [45]	validation_0-error:0.19048	validation_0-logloss:0.44467
# [46]	validation_0-error:0.19048	validation_0-logloss:0.44670
# [47]	validation_0-error:0.19913	validation_0-logloss:0.44578
# [48]	validation_0-error:0.20346	validation_0-logloss:0.45005
# [0]	validation_0-error:0.36797	validation_0-logloss:0.63723
# [1]	validation_0-error:0.36797	validation_0-logloss:0.61066
# [2]	validation_0-error:0.36797	validation_0-logloss:0.59593
# [3]	validation_0-error:0.34632	validation_0-logloss:0.57588
# [4]	validation_0-error:0.31602	validation_0-logloss:0.56326
# [5]	validation_0-error:0.29437	validation_0-logloss:0.55157
# [6]	validation_0-error:0.26840	validation_0-logloss:0.53681
# [7]	validation_0-error:0.26840	validation_0-logloss:0.52653
# [8]	validation_0-error:0.26407	validation_0-logloss:0.51696
# [9]	validation_0-error:0.25541	validation_0-logloss:0.50543
# [10]	validation_0-error:0.25108	validation_0-logloss:0.49887
# [11]	validation_0-error:0.23377	validation_0-logloss:0.49262
# [12]	validation_0-error:0.24242	validation_0-logloss:0.48275
# [13]	validation_0-error:0.22944	validation_0-logloss:0.47115
# [14]	validation_0-error:0.22944	validation_0-logloss:0.46788
# [15]	validation_0-error:0.22078	validation_0-logloss:0.46599
# [16]	validation_0-error:0.22078	validation_0-logloss:0.46464
# [17]	validation_0-error:0.22078	validation_0-logloss:0.45843
# [18]	validation_0-error:0.21212	validation_0-logloss:0.45457
# [19]	validation_0-error:0.21645	validation_0-logloss:0.45269
# [20]	validation_0-error:0.20779	validation_0-logloss:0.45106
# [21]	validation_0-error:0.22511	validation_0-logloss:0.44747
# [22]	validation_0-error:0.20346	validation_0-logloss:0.44343
# [23]	validation_0-error:0.21212	validation_0-logloss:0.44227
# [24]	validation_0-error:0.22078	validation_0-logloss:0.44235
# [25]	validation_0-error:0.20346	validation_0-logloss:0.44135
# [26]	validation_0-error:0.21645	validation_0-logloss:0.44225
# [27]	validation_0-error:0.21212	validation_0-logloss:0.44058
# [28]	validation_0-error:0.21212	validation_0-logloss:0.44009
# [29]	validation_0-error:0.21212	validation_0-logloss:0.44044
# [30]	validation_0-error:0.21212	validation_0-logloss:0.43967
# [31]	validation_0-error:0.21212	validation_0-logloss:0.44017
# [32]	validation_0-error:0.21645	validation_0-logloss:0.44133
# [33]	validation_0-error:0.21212	validation_0-logloss:0.43958
# [34]	validation_0-error:0.20346	validation_0-logloss:0.43824
# [35]	validation_0-error:0.21212	validation_0-logloss:0.44022
# [36]	validation_0-error:0.20779	validation_0-logloss:0.44416
# [37]	validation_0-error:0.20346	validation_0-logloss:0.44489
# [38]	validation_0-error:0.20779	validation_0-logloss:0.44577
# [39]	validation_0-error:0.21212	validation_0-logloss:0.44676
# [40]	validation_0-error:0.20346	validation_0-logloss:0.44898
# [41]	validation_0-error:0.21212	validation_0-logloss:0.44973
# [42]	validation_0-error:0.21212	validation_0-logloss:0.45324
# [43]	validation_0-error:0.21212	validation_0-logloss:0.45335
# [44]	validation_0-error:0.21212	validation_0-logloss:0.45381
# [45]	validation_0-error:0.22078	validation_0-logloss:0.45190
# [46]	validation_0-error:0.21645	validation_0-logloss:0.44834
# [47]	validation_0-error:0.20779	validation_0-logloss:0.44929
# [48]	validation_0-error:0.21212	validation_0-logloss:0.45155
# [49]	validation_0-error:0.21212	validation_0-logloss:0.45184
# [0]	validation_0-error:0.36797	validation_0-logloss:0.63138
# [1]	validation_0-error:0.36797	validation_0-logloss:0.60696
# [2]	validation_0-error:0.36797	validation_0-logloss:0.58244
# [3]	validation_0-error:0.32468	validation_0-logloss:0.56074
# [4]	validation_0-error:0.29437	validation_0-logloss:0.54456
# [5]	validation_0-error:0.25974	validation_0-logloss:0.53361
# [6]	validation_0-error:0.23377	validation_0-logloss:0.52120
# [7]	validation_0-error:0.24242	validation_0-logloss:0.51676
# [8]	validation_0-error:0.24242	validation_0-logloss:0.51184
# [9]	validation_0-error:0.23377	validation_0-logloss:0.50306
# [10]	validation_0-error:0.24675	validation_0-logloss:0.49543
# [11]	validation_0-error:0.23377	validation_0-logloss:0.48988
# [12]	validation_0-error:0.24242	validation_0-logloss:0.49071
# [13]	validation_0-error:0.22944	validation_0-logloss:0.48239
# [14]	validation_0-error:0.21645	validation_0-logloss:0.47630
# [15]	validation_0-error:0.22078	validation_0-logloss:0.47551
# [16]	validation_0-error:0.21645	validation_0-logloss:0.47283
# [17]	validation_0-error:0.20346	validation_0-logloss:0.46939
# [18]	validation_0-error:0.19913	validation_0-logloss:0.46800
# [19]	validation_0-error:0.19913	validation_0-logloss:0.46458
# [20]	validation_0-error:0.20779	validation_0-logloss:0.46335
# [21]	validation_0-error:0.19481	validation_0-logloss:0.46427
# [22]	validation_0-error:0.21212	validation_0-logloss:0.46327
# [23]	validation_0-error:0.21645	validation_0-logloss:0.46466
# [24]	validation_0-error:0.21212	validation_0-logloss:0.46053
# [25]	validation_0-error:0.19913	validation_0-logloss:0.45248
# [26]	validation_0-error:0.20346	validation_0-logloss:0.45305
# [27]	validation_0-error:0.19913	validation_0-logloss:0.45341
# [28]	validation_0-error:0.20346	validation_0-logloss:0.45373
# [29]	validation_0-error:0.20346	validation_0-logloss:0.45421
# [30]	validation_0-error:0.19913	validation_0-logloss:0.45578
# [31]	validation_0-error:0.20779	validation_0-logloss:0.45335
# [32]	validation_0-error:0.21212	validation_0-logloss:0.45300
# [33]	validation_0-error:0.19913	validation_0-logloss:0.45273
# [34]	validation_0-error:0.20346	validation_0-logloss:0.45257
# [35]	validation_0-error:0.20779	validation_0-logloss:0.44935
# [36]	validation_0-error:0.20779	validation_0-logloss:0.44916
# [37]	validation_0-error:0.21212	validation_0-logloss:0.44877
# [38]	validation_0-error:0.20346	validation_0-logloss:0.44885
# [39]	validation_0-error:0.20346	validation_0-logloss:0.45112
# [40]	validation_0-error:0.20779	validation_0-logloss:0.44758
# [41]	validation_0-error:0.20779	validation_0-logloss:0.44920
# [42]	validation_0-error:0.20779	validation_0-logloss:0.45015
# [43]	validation_0-error:0.21212	validation_0-logloss:0.45050
# [44]	validation_0-error:0.19481	validation_0-logloss:0.45227
# [45]	validation_0-error:0.19481	validation_0-logloss:0.45189
# [46]	validation_0-error:0.20346	validation_0-logloss:0.45189
# [47]	validation_0-error:0.20346	validation_0-logloss:0.45163
# [48]	validation_0-error:0.20346	validation_0-logloss:0.45038
# [49]	validation_0-error:0.19913	validation_0-logloss:0.45343
# [0]	validation_0-error:0.36797	validation_0-logloss:0.63204
# [1]	validation_0-error:0.36797	validation_0-logloss:0.60263
# [2]	validation_0-error:0.36797	validation_0-logloss:0.57828
# [3]	validation_0-error:0.31169	validation_0-logloss:0.56236
# [4]	validation_0-error:0.27273	validation_0-logloss:0.54472
# [5]	validation_0-error:0.24242	validation_0-logloss:0.52770
# [6]	validation_0-error:0.24242	validation_0-logloss:0.51593
# [7]	validation_0-error:0.23810	validation_0-logloss:0.50739
# [8]	validation_0-error:0.22944	validation_0-logloss:0.50172
# [9]	validation_0-error:0.23377	validation_0-logloss:0.49632
# [10]	validation_0-error:0.22078	validation_0-logloss:0.48940
# [11]	validation_0-error:0.22944	validation_0-logloss:0.48178
# [12]	validation_0-error:0.23377	validation_0-logloss:0.47961
# [13]	validation_0-error:0.21645	validation_0-logloss:0.47067
# [14]	validation_0-error:0.22078	validation_0-logloss:0.46667
# [15]	validation_0-error:0.21645	validation_0-logloss:0.46765
# [16]	validation_0-error:0.21212	validation_0-logloss:0.46459
# [17]	validation_0-error:0.22078	validation_0-logloss:0.46462
# [18]	validation_0-error:0.21645	validation_0-logloss:0.46054
# [19]	validation_0-error:0.21212	validation_0-logloss:0.45956
# [20]	validation_0-error:0.21212	validation_0-logloss:0.45933
# [21]	validation_0-error:0.20779	validation_0-logloss:0.45556
# [22]	validation_0-error:0.21212	validation_0-logloss:0.45550
# [23]	validation_0-error:0.21645	validation_0-logloss:0.45878
# [24]	validation_0-error:0.21645	validation_0-logloss:0.45717
# [25]	validation_0-error:0.21645	validation_0-logloss:0.45814
# [26]	validation_0-error:0.21645	validation_0-logloss:0.45907
# [27]	validation_0-error:0.21212	validation_0-logloss:0.45930
# [28]	validation_0-error:0.21212	validation_0-logloss:0.45873
# [29]	validation_0-error:0.22078	validation_0-logloss:0.45516
# [30]	validation_0-error:0.22078	validation_0-logloss:0.45604
# [31]	validation_0-error:0.22944	validation_0-logloss:0.45879
# [32]	validation_0-error:0.22511	validation_0-logloss:0.45789
# [33]	validation_0-error:0.22511	validation_0-logloss:0.45513
# [34]	validation_0-error:0.22078	validation_0-logloss:0.45437
# [35]	validation_0-error:0.22511	validation_0-logloss:0.45188
# [36]	validation_0-error:0.22511	validation_0-logloss:0.45246
# [37]	validation_0-error:0.22944	validation_0-logloss:0.45496
# [38]	validation_0-error:0.22944	validation_0-logloss:0.45693
# [39]	validation_0-error:0.22944	validation_0-logloss:0.45642
# [40]	validation_0-error:0.22944	validation_0-logloss:0.45740
# [41]	validation_0-error:0.22511	validation_0-logloss:0.45856
# [42]	validation_0-error:0.22944	validation_0-logloss:0.46018
# [43]	validation_0-error:0.22511	validation_0-logloss:0.46111
# [44]	validation_0-error:0.22944	validation_0-logloss:0.46370
# [45]	validation_0-error:0.23377	validation_0-logloss:0.46431
# [46]	validation_0-error:0.22944	validation_0-logloss:0.46558
# [47]	validation_0-error:0.22511	validation_0-logloss:0.46216
# [48]	validation_0-error:0.23377	validation_0-logloss:0.46588
# [49]	validation_0-error:0.22511	validation_0-logloss:0.46553
# [0]	validation_0-error:0.36797	validation_0-logloss:0.62980
# [1]	validation_0-error:0.36797	validation_0-logloss:0.60525
# [2]	validation_0-error:0.36797	validation_0-logloss:0.57974
# [3]	validation_0-error:0.30736	validation_0-logloss:0.56117
# [4]	validation_0-error:0.25974	validation_0-logloss:0.54860
# [5]	validation_0-error:0.22944	validation_0-logloss:0.52716
# [6]	validation_0-error:0.22078	validation_0-logloss:0.51827
# [7]	validation_0-error:0.22078	validation_0-logloss:0.50877
# [8]	validation_0-error:0.21645	validation_0-logloss:0.50253
# [9]	validation_0-error:0.20779	validation_0-logloss:0.49384
# [10]	validation_0-error:0.21212	validation_0-logloss:0.49109
# [11]	validation_0-error:0.21645	validation_0-logloss:0.48732
# [12]	validation_0-error:0.20779	validation_0-logloss:0.48342
# [13]	validation_0-error:0.20779	validation_0-logloss:0.47480
# [14]	validation_0-error:0.19913	validation_0-logloss:0.46965
# [15]	validation_0-error:0.20346	validation_0-logloss:0.46668
# [16]	validation_0-error:0.19913	validation_0-logloss:0.46361
# [17]	validation_0-error:0.20346	validation_0-logloss:0.46617
# [18]	validation_0-error:0.20346	validation_0-logloss:0.46006
# [19]	validation_0-error:0.19913	validation_0-logloss:0.45866
# [20]	validation_0-error:0.20346	validation_0-logloss:0.45359
# [21]	validation_0-error:0.20346	validation_0-logloss:0.45206
# [22]	validation_0-error:0.20779	validation_0-logloss:0.44993
# [23]	validation_0-error:0.21645	validation_0-logloss:0.45298
# [24]	validation_0-error:0.22511	validation_0-logloss:0.45264
# [25]	validation_0-error:0.23377	validation_0-logloss:0.45114
# [26]	validation_0-error:0.22944	validation_0-logloss:0.44985
# [27]	validation_0-error:0.22944	validation_0-logloss:0.45346
# [28]	validation_0-error:0.23377	validation_0-logloss:0.45497
# [29]	validation_0-error:0.22078	validation_0-logloss:0.45564
# [30]	validation_0-error:0.22511	validation_0-logloss:0.45365
# [31]	validation_0-error:0.22511	validation_0-logloss:0.45542
# [32]	validation_0-error:0.22511	validation_0-logloss:0.45480
# [33]	validation_0-error:0.22511	validation_0-logloss:0.45287
# [34]	validation_0-error:0.22078	validation_0-logloss:0.45220
# [35]	validation_0-error:0.22078	validation_0-logloss:0.45038
# [36]	validation_0-error:0.22511	validation_0-logloss:0.44721
# [37]	validation_0-error:0.21212	validation_0-logloss:0.44677
# [38]	validation_0-error:0.21212	validation_0-logloss:0.44831
# [39]	validation_0-error:0.21212	validation_0-logloss:0.44883
# [40]	validation_0-error:0.21645	validation_0-logloss:0.45006
# [41]	validation_0-error:0.21645	validation_0-logloss:0.45141
# [42]	validation_0-error:0.21645	validation_0-logloss:0.45056
# [43]	validation_0-error:0.21645	validation_0-logloss:0.45108
# [44]	validation_0-error:0.22078	validation_0-logloss:0.45413
# [45]	validation_0-error:0.21645	validation_0-logloss:0.45655
# [46]	validation_0-error:0.22511	validation_0-logloss:0.45306
# [47]	validation_0-error:0.22078	validation_0-logloss:0.45199
# [48]	validation_0-error:0.22511	validation_0-logloss:0.45413
# [49]	validation_0-error:0.22944	validation_0-logloss:0.45499
# [0]	validation_0-error:0.27706	validation_0-logloss:0.56934
# [1]	validation_0-error:0.24675	validation_0-logloss:0.55245
# [2]	validation_0-error:0.27273	validation_0-logloss:0.52114
# [3]	validation_0-error:0.26840	validation_0-logloss:0.49606
# [4]	validation_0-error:0.23377	validation_0-logloss:0.47885
# [5]	validation_0-error:0.25974	validation_0-logloss:0.47733
# [6]	validation_0-error:0.24675	validation_0-logloss:0.48683
# [7]	validation_0-error:0.22944	validation_0-logloss:0.47017
# [8]	validation_0-error:0.23377	validation_0-logloss:0.45930
# [9]	validation_0-error:0.22511	validation_0-logloss:0.47244
# [10]	validation_0-error:0.22078	validation_0-logloss:0.48349
# [11]	validation_0-error:0.22944	validation_0-logloss:0.48735
# [12]	validation_0-error:0.24242	validation_0-logloss:0.50127
# [13]	validation_0-error:0.25108	validation_0-logloss:0.50274
# [14]	validation_0-error:0.25108	validation_0-logloss:0.51198
# [15]	validation_0-error:0.22511	validation_0-logloss:0.50750
# [16]	validation_0-error:0.22511	validation_0-logloss:0.50221
# [17]	validation_0-error:0.23377	validation_0-logloss:0.49373
# [18]	validation_0-error:0.22944	validation_0-logloss:0.50232
# [19]	validation_0-error:0.23377	validation_0-logloss:0.50493
# [0]	validation_0-error:0.28571	validation_0-logloss:0.59553
# [1]	validation_0-error:0.28571	validation_0-logloss:0.53690
# [2]	validation_0-error:0.26840	validation_0-logloss:0.52643
# [3]	validation_0-error:0.24675	validation_0-logloss:0.49838
# [4]	validation_0-error:0.24675	validation_0-logloss:0.48713
# [5]	validation_0-error:0.24242	validation_0-logloss:0.47644
# [6]	validation_0-error:0.21645	validation_0-logloss:0.46568
# [7]	validation_0-error:0.22511	validation_0-logloss:0.46164
# [8]	validation_0-error:0.24242	validation_0-logloss:0.46877
# [9]	validation_0-error:0.20779	validation_0-logloss:0.47324
# [10]	validation_0-error:0.21212	validation_0-logloss:0.46844
# [11]	validation_0-error:0.21212	validation_0-logloss:0.46743
# [12]	validation_0-error:0.21645	validation_0-logloss:0.48263
# [13]	validation_0-error:0.23377	validation_0-logloss:0.49977
# [14]	validation_0-error:0.24675	validation_0-logloss:0.49117
# [15]	validation_0-error:0.23377	validation_0-logloss:0.48364
# [16]	validation_0-error:0.22944	validation_0-logloss:0.49523
# [17]	validation_0-error:0.22511	validation_0-logloss:0.47555
# [18]	validation_0-error:0.23377	validation_0-logloss:0.50451
# [19]	validation_0-error:0.24675	validation_0-logloss:0.49320
# [0]	validation_0-error:0.25974	validation_0-logloss:0.59012
# [1]	validation_0-error:0.22511	validation_0-logloss:0.51739
# [2]	validation_0-error:0.21645	validation_0-logloss:0.48862
# [3]	validation_0-error:0.18615	validation_0-logloss:0.46741
# [4]	validation_0-error:0.16883	validation_0-logloss:0.44111
# [5]	validation_0-error:0.21645	validation_0-logloss:0.46747
# [6]	validation_0-error:0.22078	validation_0-logloss:0.47671
# [7]	validation_0-error:0.20779	validation_0-logloss:0.48180
# [8]	validation_0-error:0.22511	validation_0-logloss:0.48508
# [9]	validation_0-error:0.20346	validation_0-logloss:0.48545
# [10]	validation_0-error:0.22944	validation_0-logloss:0.48087
# [11]	validation_0-error:0.23377	validation_0-logloss:0.49181
# [12]	validation_0-error:0.22078	validation_0-logloss:0.49688
# [13]	validation_0-error:0.23810	validation_0-logloss:0.50367
# [14]	validation_0-error:0.23810	validation_0-logloss:0.50640
# [15]	validation_0-error:0.23377	validation_0-logloss:0.49478
# [16]	validation_0-error:0.24675	validation_0-logloss:0.51822
# [17]	validation_0-error:0.22511	validation_0-logloss:0.51708
# [18]	validation_0-error:0.21645	validation_0-logloss:0.51360
# [19]	validation_0-error:0.20346	validation_0-logloss:0.51332
# [0]	validation_0-error:0.27706	validation_0-logloss:0.57910
# [1]	validation_0-error:0.20779	validation_0-logloss:0.51109
# [2]	validation_0-error:0.21645	validation_0-logloss:0.49529
# [3]	validation_0-error:0.19913	validation_0-logloss:0.48921
# [4]	validation_0-error:0.20779	validation_0-logloss:0.47663
# [5]	validation_0-error:0.22944	validation_0-logloss:0.46978
# [6]	validation_0-error:0.24675	validation_0-logloss:0.48585
# [7]	validation_0-error:0.24675	validation_0-logloss:0.49123
# [8]	validation_0-error:0.23810	validation_0-logloss:0.50342
# [9]	validation_0-error:0.23377	validation_0-logloss:0.50017
# [10]	validation_0-error:0.24675	validation_0-logloss:0.51259
# [11]	validation_0-error:0.25541	validation_0-logloss:0.52381
# [12]	validation_0-error:0.22944	validation_0-logloss:0.52388
# [13]	validation_0-error:0.24242	validation_0-logloss:0.52833
# [14]	validation_0-error:0.23810	validation_0-logloss:0.53655
# [15]	validation_0-error:0.25108	validation_0-logloss:0.54738
# [16]	validation_0-error:0.25108	validation_0-logloss:0.54204
# [17]	validation_0-error:0.25108	validation_0-logloss:0.55667
# [18]	validation_0-error:0.26840	validation_0-logloss:0.55085
# [19]	validation_0-error:0.25541	validation_0-logloss:0.55780
# [0]	validation_0-error:0.24242	validation_0-logloss:0.57690
# [1]	validation_0-error:0.26407	validation_0-logloss:0.53980
# [2]	validation_0-error:0.21645	validation_0-logloss:0.51891
# [3]	validation_0-error:0.22944	validation_0-logloss:0.50306
# [4]	validation_0-error:0.21212	validation_0-logloss:0.49694
# [5]	validation_0-error:0.21212	validation_0-logloss:0.49286
# [6]	validation_0-error:0.21645	validation_0-logloss:0.50539
# [7]	validation_0-error:0.20779	validation_0-logloss:0.50408
# [8]	validation_0-error:0.21212	validation_0-logloss:0.50867
# [9]	validation_0-error:0.20346	validation_0-logloss:0.50265
# [10]	validation_0-error:0.22944	validation_0-logloss:0.52425
# [11]	validation_0-error:0.24675	validation_0-logloss:0.53182
# [12]	validation_0-error:0.25541	validation_0-logloss:0.54030
# [13]	validation_0-error:0.23377	validation_0-logloss:0.54481
# [14]	validation_0-error:0.22511	validation_0-logloss:0.52582
# [15]	validation_0-error:0.24242	validation_0-logloss:0.52885
# [16]	validation_0-error:0.25541	validation_0-logloss:0.53722
# [17]	validation_0-error:0.24675	validation_0-logloss:0.54222
# [18]	validation_0-error:0.25541	validation_0-logloss:0.52072
# [19]	validation_0-error:0.25974	validation_0-logloss:0.55569
# [0]	validation_0-error:0.36797	validation_0-logloss:0.58281
# [1]	validation_0-error:0.29437	validation_0-logloss:0.53090
# [2]	validation_0-error:0.26840	validation_0-logloss:0.51220
# [3]	validation_0-error:0.22944	validation_0-logloss:0.48856
# [4]	validation_0-error:0.21212	validation_0-logloss:0.46073
# [5]	validation_0-error:0.19481	validation_0-logloss:0.44958
# [6]	validation_0-error:0.20779	validation_0-logloss:0.43588
# [7]	validation_0-error:0.19481	validation_0-logloss:0.43357
# [8]	validation_0-error:0.19481	validation_0-logloss:0.44531
# [9]	validation_0-error:0.20779	validation_0-logloss:0.44645
# [10]	validation_0-error:0.20779	validation_0-logloss:0.44856
# [11]	validation_0-error:0.21212	validation_0-logloss:0.45265
# [12]	validation_0-error:0.21645	validation_0-logloss:0.45494
# [13]	validation_0-error:0.20779	validation_0-logloss:0.44887
# [14]	validation_0-error:0.21645	validation_0-logloss:0.44977
# [15]	validation_0-error:0.21212	validation_0-logloss:0.44883
# [16]	validation_0-error:0.21645	validation_0-logloss:0.45012
# [17]	validation_0-error:0.22511	validation_0-logloss:0.44996
# [18]	validation_0-error:0.21645	validation_0-logloss:0.46215
# [19]	validation_0-error:0.19913	validation_0-logloss:0.46172
# [20]	validation_0-error:0.20779	validation_0-logloss:0.46568
# [21]	validation_0-error:0.21645	validation_0-logloss:0.47437
# [22]	validation_0-error:0.21645	validation_0-logloss:0.47807
# [23]	validation_0-error:0.22078	validation_0-logloss:0.48595
# [24]	validation_0-error:0.21645	validation_0-logloss:0.48508
# [25]	validation_0-error:0.22511	validation_0-logloss:0.48713
# [26]	validation_0-error:0.22511	validation_0-logloss:0.49645
# [0]	validation_0-error:0.36797	validation_0-logloss:0.61086
# [1]	validation_0-error:0.30303	validation_0-logloss:0.56306
# [2]	validation_0-error:0.25541	validation_0-logloss:0.54386
# [3]	validation_0-error:0.24242	validation_0-logloss:0.52641
# [4]	validation_0-error:0.25541	validation_0-logloss:0.51444
# [5]	validation_0-error:0.23810	validation_0-logloss:0.49064
# [6]	validation_0-error:0.22511	validation_0-logloss:0.47815
# [7]	validation_0-error:0.22511	validation_0-logloss:0.47255
# [8]	validation_0-error:0.21645	validation_0-logloss:0.47203
# [9]	validation_0-error:0.22078	validation_0-logloss:0.46612
# [10]	validation_0-error:0.21645	validation_0-logloss:0.46698
# [11]	validation_0-error:0.21645	validation_0-logloss:0.46332
# [12]	validation_0-error:0.20779	validation_0-logloss:0.45686
# [13]	validation_0-error:0.17316	validation_0-logloss:0.44609
# [14]	validation_0-error:0.19048	validation_0-logloss:0.44723
# [15]	validation_0-error:0.18182	validation_0-logloss:0.44914
# [16]	validation_0-error:0.19481	validation_0-logloss:0.45016
# [17]	validation_0-error:0.19048	validation_0-logloss:0.44976
# [18]	validation_0-error:0.19048	validation_0-logloss:0.45565
# [19]	validation_0-error:0.18615	validation_0-logloss:0.45835
# [20]	validation_0-error:0.20779	validation_0-logloss:0.46032
# [21]	validation_0-error:0.21645	validation_0-logloss:0.46552
# [22]	validation_0-error:0.20346	validation_0-logloss:0.46193
# [23]	validation_0-error:0.19913	validation_0-logloss:0.46816
# [24]	validation_0-error:0.20779	validation_0-logloss:0.46802
# [25]	validation_0-error:0.21645	validation_0-logloss:0.47137
# [26]	validation_0-error:0.22078	validation_0-logloss:0.46009
# [27]	validation_0-error:0.21645	validation_0-logloss:0.45603
# [28]	validation_0-error:0.21645	validation_0-logloss:0.44706
# [29]	validation_0-error:0.22944	validation_0-logloss:0.45665
# [30]	validation_0-error:0.22511	validation_0-logloss:0.45636
# [31]	validation_0-error:0.20779	validation_0-logloss:0.45452
# [32]	validation_0-error:0.21645	validation_0-logloss:0.46279
# [33]	validation_0-error:0.23377	validation_0-logloss:0.46872
# [0]	validation_0-error:0.36797	validation_0-logloss:0.59647
# [1]	validation_0-error:0.27273	validation_0-logloss:0.54665
# [2]	validation_0-error:0.24242	validation_0-logloss:0.51110
# [3]	validation_0-error:0.22078	validation_0-logloss:0.47623
# [4]	validation_0-error:0.19913	validation_0-logloss:0.45230
# [5]	validation_0-error:0.19913	validation_0-logloss:0.44312
# [6]	validation_0-error:0.19048	validation_0-logloss:0.43455
# [7]	validation_0-error:0.18182	validation_0-logloss:0.44569
# [8]	validation_0-error:0.18615	validation_0-logloss:0.44878
# [9]	validation_0-error:0.18182	validation_0-logloss:0.45347
# [10]	validation_0-error:0.17316	validation_0-logloss:0.45660
# [11]	validation_0-error:0.18615	validation_0-logloss:0.45940
# [12]	validation_0-error:0.20779	validation_0-logloss:0.47355
# [13]	validation_0-error:0.21645	validation_0-logloss:0.47666
# [14]	validation_0-error:0.21212	validation_0-logloss:0.47098
# [15]	validation_0-error:0.21645	validation_0-logloss:0.47303
# [16]	validation_0-error:0.21645	validation_0-logloss:0.48098
# [17]	validation_0-error:0.21645	validation_0-logloss:0.48114
# [18]	validation_0-error:0.20346	validation_0-logloss:0.46928
# [19]	validation_0-error:0.22078	validation_0-logloss:0.47760
# [20]	validation_0-error:0.22944	validation_0-logloss:0.49374
# [21]	validation_0-error:0.22944	validation_0-logloss:0.49683
# [22]	validation_0-error:0.23377	validation_0-logloss:0.49923
# [23]	validation_0-error:0.24242	validation_0-logloss:0.50286
# [24]	validation_0-error:0.23810	validation_0-logloss:0.50511
# [25]	validation_0-error:0.23810	validation_0-logloss:0.50760
# [0]	validation_0-error:0.36797	validation_0-logloss:0.59901
# [1]	validation_0-error:0.29004	validation_0-logloss:0.54369
# [2]	validation_0-error:0.22944	validation_0-logloss:0.51158
# [3]	validation_0-error:0.22511	validation_0-logloss:0.49072
# [4]	validation_0-error:0.22511	validation_0-logloss:0.46457
# [5]	validation_0-error:0.20779	validation_0-logloss:0.44453
# [6]	validation_0-error:0.20779	validation_0-logloss:0.44084
# [7]	validation_0-error:0.20779	validation_0-logloss:0.44119
# [8]	validation_0-error:0.21645	validation_0-logloss:0.43843
# [9]	validation_0-error:0.20346	validation_0-logloss:0.43606
# [10]	validation_0-error:0.19048	validation_0-logloss:0.43298
# [11]	validation_0-error:0.19048	validation_0-logloss:0.43234
# [12]	validation_0-error:0.19048	validation_0-logloss:0.44329
# [13]	validation_0-error:0.19481	validation_0-logloss:0.43026
# [14]	validation_0-error:0.18182	validation_0-logloss:0.43649
# [15]	validation_0-error:0.19048	validation_0-logloss:0.44091
# [16]	validation_0-error:0.19481	validation_0-logloss:0.44023
# [17]	validation_0-error:0.20346	validation_0-logloss:0.44157
# [18]	validation_0-error:0.18615	validation_0-logloss:0.43875
# [19]	validation_0-error:0.19048	validation_0-logloss:0.43968
# [20]	validation_0-error:0.19481	validation_0-logloss:0.43994
# [21]	validation_0-error:0.20346	validation_0-logloss:0.44852
# [22]	validation_0-error:0.19913	validation_0-logloss:0.44897
# [23]	validation_0-error:0.20779	validation_0-logloss:0.45968
# [24]	validation_0-error:0.21212	validation_0-logloss:0.46628
# [25]	validation_0-error:0.21212	validation_0-logloss:0.46046
# [26]	validation_0-error:0.20346	validation_0-logloss:0.45683
# [27]	validation_0-error:0.20779	validation_0-logloss:0.46926
# [28]	validation_0-error:0.21645	validation_0-logloss:0.47144
# [29]	validation_0-error:0.20779	validation_0-logloss:0.46562
# [30]	validation_0-error:0.21645	validation_0-logloss:0.47669
# [31]	validation_0-error:0.21645	validation_0-logloss:0.48581
# [32]	validation_0-error:0.21645	validation_0-logloss:0.48544
# [33]	validation_0-error:0.21645	validation_0-logloss:0.47223
# [0]	validation_0-error:0.36797	validation_0-logloss:0.59346
# [1]	validation_0-error:0.29004	validation_0-logloss:0.55240
# [2]	validation_0-error:0.21645	validation_0-logloss:0.51785
# [3]	validation_0-error:0.21212	validation_0-logloss:0.49016
# [4]	validation_0-error:0.20779	validation_0-logloss:0.47677
# [5]	validation_0-error:0.19481	validation_0-logloss:0.45031
# [6]	validation_0-error:0.19048	validation_0-logloss:0.45412
# [7]	validation_0-error:0.19913	validation_0-logloss:0.44802
# [8]	validation_0-error:0.19048	validation_0-logloss:0.44742
# [9]	validation_0-error:0.19048	validation_0-logloss:0.44613
# [10]	validation_0-error:0.19913	validation_0-logloss:0.45218
# [11]	validation_0-error:0.20346	validation_0-logloss:0.45341
# [12]	validation_0-error:0.21212	validation_0-logloss:0.45480
# [13]	validation_0-error:0.21212	validation_0-logloss:0.46052
# [14]	validation_0-error:0.21212	validation_0-logloss:0.46330
# [15]	validation_0-error:0.21645	validation_0-logloss:0.46456
# [16]	validation_0-error:0.20779	validation_0-logloss:0.46398
# [17]	validation_0-error:0.20779	validation_0-logloss:0.46884
# [18]	validation_0-error:0.20779	validation_0-logloss:0.46260
# [19]	validation_0-error:0.20346	validation_0-logloss:0.46177
# [20]	validation_0-error:0.19481	validation_0-logloss:0.45844
# [21]	validation_0-error:0.20779	validation_0-logloss:0.46387
# [22]	validation_0-error:0.22078	validation_0-logloss:0.46733
# [23]	validation_0-error:0.21645	validation_0-logloss:0.47005
# [24]	validation_0-error:0.22078	validation_0-logloss:0.46831
# [25]	validation_0-error:0.21212	validation_0-logloss:0.46910
# [26]	validation_0-error:0.22944	validation_0-logloss:0.47152
# [27]	validation_0-error:0.23377	validation_0-logloss:0.48286
# [28]	validation_0-error:0.23810	validation_0-logloss:0.48023
# [0]	validation_0-error:0.36797	validation_0-logloss:0.62257
# [1]	validation_0-error:0.36797	validation_0-logloss:0.60019
# [2]	validation_0-error:0.36797	validation_0-logloss:0.58363
# [3]	validation_0-error:0.31602	validation_0-logloss:0.55907
# [4]	validation_0-error:0.28139	validation_0-logloss:0.54157
# [5]	validation_0-error:0.26407	validation_0-logloss:0.52870
# [6]	validation_0-error:0.24675	validation_0-logloss:0.51762
# [7]	validation_0-error:0.24242	validation_0-logloss:0.50959
# [8]	validation_0-error:0.22078	validation_0-logloss:0.50267
# [9]	validation_0-error:0.21645	validation_0-logloss:0.49063
# [10]	validation_0-error:0.22511	validation_0-logloss:0.48341
# [11]	validation_0-error:0.21212	validation_0-logloss:0.47706
# [12]	validation_0-error:0.21645	validation_0-logloss:0.46950
# [13]	validation_0-error:0.20779	validation_0-logloss:0.46420
# [14]	validation_0-error:0.22511	validation_0-logloss:0.45739
# [0]	validation_0-error:0.36797	validation_0-logloss:0.63273
# [1]	validation_0-error:0.36797	validation_0-logloss:0.60496
# [2]	validation_0-error:0.36797	validation_0-logloss:0.58315
# [3]	validation_0-error:0.30303	validation_0-logloss:0.57092
# [4]	validation_0-error:0.28139	validation_0-logloss:0.55768
# [5]	validation_0-error:0.23377	validation_0-logloss:0.54069
# [6]	validation_0-error:0.21645	validation_0-logloss:0.52506
# [7]	validation_0-error:0.20346	validation_0-logloss:0.51417
# [8]	validation_0-error:0.20346	validation_0-logloss:0.50626
# [9]	validation_0-error:0.17749	validation_0-logloss:0.49741
# [10]	validation_0-error:0.19048	validation_0-logloss:0.49537
# [11]	validation_0-error:0.19913	validation_0-logloss:0.49133
# [12]	validation_0-error:0.20346	validation_0-logloss:0.48688
# [13]	validation_0-error:0.20346	validation_0-logloss:0.48145
# [14]	validation_0-error:0.20346	validation_0-logloss:0.47480
# [0]	validation_0-error:0.36797	validation_0-logloss:0.63479
# [1]	validation_0-error:0.36797	validation_0-logloss:0.61016
# [2]	validation_0-error:0.36797	validation_0-logloss:0.59388
# [3]	validation_0-error:0.31602	validation_0-logloss:0.56693
# [4]	validation_0-error:0.32035	validation_0-logloss:0.55225
# [5]	validation_0-error:0.27706	validation_0-logloss:0.53852
# [6]	validation_0-error:0.25541	validation_0-logloss:0.52714
# [7]	validation_0-error:0.22511	validation_0-logloss:0.51338
# [8]	validation_0-error:0.21645	validation_0-logloss:0.50646
# [9]	validation_0-error:0.20779	validation_0-logloss:0.49777
# [10]	validation_0-error:0.22078	validation_0-logloss:0.49375
# [11]	validation_0-error:0.21212	validation_0-logloss:0.48875
# [12]	validation_0-error:0.20779	validation_0-logloss:0.48169
# [13]	validation_0-error:0.20346	validation_0-logloss:0.47830
# [14]	validation_0-error:0.20346	validation_0-logloss:0.47414
# [0]	validation_0-error:0.36797	validation_0-logloss:0.62766
# [1]	validation_0-error:0.36797	validation_0-logloss:0.59917
# [2]	validation_0-error:0.36797	validation_0-logloss:0.57732
# [3]	validation_0-error:0.28571	validation_0-logloss:0.55967
# [4]	validation_0-error:0.25108	validation_0-logloss:0.54172
# [5]	validation_0-error:0.24675	validation_0-logloss:0.52533
# [6]	validation_0-error:0.23810	validation_0-logloss:0.51623
# [7]	validation_0-error:0.24242	validation_0-logloss:0.50543
# [8]	validation_0-error:0.21645	validation_0-logloss:0.49412
# [9]	validation_0-error:0.21212	validation_0-logloss:0.48699
# [10]	validation_0-error:0.21212	validation_0-logloss:0.48051
# [11]	validation_0-error:0.22078	validation_0-logloss:0.47456
# [12]	validation_0-error:0.22078	validation_0-logloss:0.47166
# [13]	validation_0-error:0.22511	validation_0-logloss:0.46707
# [14]	validation_0-error:0.22078	validation_0-logloss:0.46333
# [0]	validation_0-error:0.36797	validation_0-logloss:0.63179
# [1]	validation_0-error:0.36797	validation_0-logloss:0.61059
# [2]	validation_0-error:0.35065	validation_0-logloss:0.59035
# [3]	validation_0-error:0.29870	validation_0-logloss:0.56596
# [4]	validation_0-error:0.25974	validation_0-logloss:0.55217
# [5]	validation_0-error:0.26407	validation_0-logloss:0.53215
# [6]	validation_0-error:0.24675	validation_0-logloss:0.51824
# [7]	validation_0-error:0.25974	validation_0-logloss:0.51306
# [8]	validation_0-error:0.23377	validation_0-logloss:0.50013
# [9]	validation_0-error:0.22944	validation_0-logloss:0.48921
# [10]	validation_0-error:0.22078	validation_0-logloss:0.48494
# [11]	validation_0-error:0.21645	validation_0-logloss:0.47793
# [12]	validation_0-error:0.21212	validation_0-logloss:0.47405
# [13]	validation_0-error:0.20779	validation_0-logloss:0.46983
# [14]	validation_0-error:0.20779	validation_0-logloss:0.46637
# [0]	validation_0-error:0.24242	validation_0-logloss:0.53864
# [1]	validation_0-error:0.21645	validation_0-logloss:0.50060
# [2]	validation_0-error:0.24242	validation_0-logloss:0.49348
# [3]	validation_0-error:0.24242	validation_0-logloss:0.48057
# [4]	validation_0-error:0.23377	validation_0-logloss:0.47074
# [5]	validation_0-error:0.21645	validation_0-logloss:0.45665
# [6]	validation_0-error:0.22944	validation_0-logloss:0.45805
# [7]	validation_0-error:0.21212	validation_0-logloss:0.45275
# [8]	validation_0-error:0.20779	validation_0-logloss:0.44481
# [9]	validation_0-error:0.22078	validation_0-logloss:0.45279
# [10]	validation_0-error:0.21212	validation_0-logloss:0.45301
# [11]	validation_0-error:0.20346	validation_0-logloss:0.45225
# [12]	validation_0-error:0.20779	validation_0-logloss:0.46557
# [13]	validation_0-error:0.22078	validation_0-logloss:0.46083
# [14]	validation_0-error:0.19481	validation_0-logloss:0.46388
# [15]	validation_0-error:0.19913	validation_0-logloss:0.47141
# [16]	validation_0-error:0.20779	validation_0-logloss:0.47449
# [17]	validation_0-error:0.21212	validation_0-logloss:0.48108
# [18]	validation_0-error:0.20779	validation_0-logloss:0.48816
# [19]	validation_0-error:0.20346	validation_0-logloss:0.49222
# [20]	validation_0-error:0.20346	validation_0-logloss:0.49348
# [21]	validation_0-error:0.19913	validation_0-logloss:0.50771
# [22]	validation_0-error:0.21645	validation_0-logloss:0.51357
# [23]	validation_0-error:0.20779	validation_0-logloss:0.50986
# [24]	validation_0-error:0.21212	validation_0-logloss:0.51099
# [25]	validation_0-error:0.19913	validation_0-logloss:0.51928
# [26]	validation_0-error:0.20346	validation_0-logloss:0.52528
# [27]	validation_0-error:0.21212	validation_0-logloss:0.52365
# [0]	validation_0-error:0.27706	validation_0-logloss:0.57804
# [1]	validation_0-error:0.23377	validation_0-logloss:0.53876
# [2]	validation_0-error:0.22511	validation_0-logloss:0.51284
# [3]	validation_0-error:0.19481	validation_0-logloss:0.48379
# [4]	validation_0-error:0.18182	validation_0-logloss:0.47928
# [5]	validation_0-error:0.20779	validation_0-logloss:0.47834
# [6]	validation_0-error:0.19913	validation_0-logloss:0.47195
# [7]	validation_0-error:0.20346	validation_0-logloss:0.48061
# [8]	validation_0-error:0.19913	validation_0-logloss:0.48059
# [9]	validation_0-error:0.20779	validation_0-logloss:0.48042
# [10]	validation_0-error:0.19481	validation_0-logloss:0.48694
# [11]	validation_0-error:0.20346	validation_0-logloss:0.48541
# [12]	validation_0-error:0.19913	validation_0-logloss:0.50035
# [13]	validation_0-error:0.19481	validation_0-logloss:0.50395
# [14]	validation_0-error:0.20779	validation_0-logloss:0.50187
# [15]	validation_0-error:0.21212	validation_0-logloss:0.49892
# [16]	validation_0-error:0.19913	validation_0-logloss:0.50513
# [17]	validation_0-error:0.21212	validation_0-logloss:0.51259
# [18]	validation_0-error:0.20346	validation_0-logloss:0.51461
# [19]	validation_0-error:0.20779	validation_0-logloss:0.51698
# [20]	validation_0-error:0.20346	validation_0-logloss:0.52246
# [21]	validation_0-error:0.22511	validation_0-logloss:0.52587
# [22]	validation_0-error:0.24242	validation_0-logloss:0.52870
# [23]	validation_0-error:0.24242	validation_0-logloss:0.53495
# [24]	validation_0-error:0.25108	validation_0-logloss:0.53993
# [25]	validation_0-error:0.24675	validation_0-logloss:0.54226
# [0]	validation_0-error:0.32035	validation_0-logloss:0.58311
# [1]	validation_0-error:0.28571	validation_0-logloss:0.53788
# [2]	validation_0-error:0.25974	validation_0-logloss:0.51109
# [3]	validation_0-error:0.22511	validation_0-logloss:0.47771
# [4]	validation_0-error:0.22511	validation_0-logloss:0.46691
# [5]	validation_0-error:0.22944	validation_0-logloss:0.47009
# [6]	validation_0-error:0.22944	validation_0-logloss:0.46452
# [7]	validation_0-error:0.23377	validation_0-logloss:0.47584
# [8]	validation_0-error:0.22078	validation_0-logloss:0.49331
# [9]	validation_0-error:0.23377	validation_0-logloss:0.49050
# [10]	validation_0-error:0.22511	validation_0-logloss:0.48935
# [11]	validation_0-error:0.21212	validation_0-logloss:0.48938
# [12]	validation_0-error:0.22511	validation_0-logloss:0.50266
# [13]	validation_0-error:0.22511	validation_0-logloss:0.51493
# [14]	validation_0-error:0.22078	validation_0-logloss:0.51959
# [15]	validation_0-error:0.22511	validation_0-logloss:0.53099
# [16]	validation_0-error:0.22078	validation_0-logloss:0.52990
# [17]	validation_0-error:0.22944	validation_0-logloss:0.53209
# [18]	validation_0-error:0.21645	validation_0-logloss:0.53377
# [19]	validation_0-error:0.21645	validation_0-logloss:0.53729
# [20]	validation_0-error:0.22944	validation_0-logloss:0.54041
# [21]	validation_0-error:0.22511	validation_0-logloss:0.54766
# [22]	validation_0-error:0.23810	validation_0-logloss:0.53976
# [23]	validation_0-error:0.22511	validation_0-logloss:0.54936
# [24]	validation_0-error:0.24242	validation_0-logloss:0.55859
# [25]	validation_0-error:0.25541	validation_0-logloss:0.55202
# [0]	validation_0-error:0.24242	validation_0-logloss:0.55784
# [1]	validation_0-error:0.22078	validation_0-logloss:0.50572
# [2]	validation_0-error:0.20779	validation_0-logloss:0.49687
# [3]	validation_0-error:0.22511	validation_0-logloss:0.47205
# [4]	validation_0-error:0.20346	validation_0-logloss:0.44807
# [5]	validation_0-error:0.22078	validation_0-logloss:0.44078
# [6]	validation_0-error:0.20346	validation_0-logloss:0.43216
# [7]	validation_0-error:0.19913	validation_0-logloss:0.44128
# [8]	validation_0-error:0.19481	validation_0-logloss:0.44643
# [9]	validation_0-error:0.17749	validation_0-logloss:0.44653
# [10]	validation_0-error:0.17749	validation_0-logloss:0.45589
# [11]	validation_0-error:0.18615	validation_0-logloss:0.45953
# [12]	validation_0-error:0.19913	validation_0-logloss:0.47236
# [13]	validation_0-error:0.19481	validation_0-logloss:0.47123
# [14]	validation_0-error:0.19913	validation_0-logloss:0.46600
# [15]	validation_0-error:0.19481	validation_0-logloss:0.46218
# [16]	validation_0-error:0.19913	validation_0-logloss:0.47107
# [17]	validation_0-error:0.20346	validation_0-logloss:0.47413
# [18]	validation_0-error:0.21212	validation_0-logloss:0.47962
# [19]	validation_0-error:0.21212	validation_0-logloss:0.48275
# [20]	validation_0-error:0.22078	validation_0-logloss:0.49063
# [21]	validation_0-error:0.21212	validation_0-logloss:0.49854
# [22]	validation_0-error:0.22511	validation_0-logloss:0.50079
# [23]	validation_0-error:0.22078	validation_0-logloss:0.50618
# [24]	validation_0-error:0.22511	validation_0-logloss:0.50726
# [25]	validation_0-error:0.22078	validation_0-logloss:0.51701
# [26]	validation_0-error:0.22511	validation_0-logloss:0.51683
# [0]	validation_0-error:0.29004	validation_0-logloss:0.57490
# [1]	validation_0-error:0.25108	validation_0-logloss:0.52322
# [2]	validation_0-error:0.22078	validation_0-logloss:0.49467
# [3]	validation_0-error:0.18182	validation_0-logloss:0.45101
# [4]	validation_0-error:0.17749	validation_0-logloss:0.43717
# [5]	validation_0-error:0.16450	validation_0-logloss:0.42113
# [6]	validation_0-error:0.19048	validation_0-logloss:0.41625
# [7]	validation_0-error:0.20779	validation_0-logloss:0.44310
# [8]	validation_0-error:0.19481	validation_0-logloss:0.44817
# [9]	validation_0-error:0.19481	validation_0-logloss:0.45598
# [10]	validation_0-error:0.20779	validation_0-logloss:0.45577
# [11]	validation_0-error:0.21212	validation_0-logloss:0.45588
# [12]	validation_0-error:0.20779	validation_0-logloss:0.44766
# [13]	validation_0-error:0.19481	validation_0-logloss:0.44959
# [14]	validation_0-error:0.20779	validation_0-logloss:0.45653
# [15]	validation_0-error:0.20779	validation_0-logloss:0.45703
# [16]	validation_0-error:0.22511	validation_0-logloss:0.46677
# [17]	validation_0-error:0.23810	validation_0-logloss:0.48656
# [18]	validation_0-error:0.22944	validation_0-logloss:0.48709
# [19]	validation_0-error:0.23377	validation_0-logloss:0.49608
# [20]	validation_0-error:0.23377	validation_0-logloss:0.49788
# [21]	validation_0-error:0.22944	validation_0-logloss:0.50036
# [22]	validation_0-error:0.22511	validation_0-logloss:0.49984
# [23]	validation_0-error:0.22078	validation_0-logloss:0.50103
# [24]	validation_0-error:0.21645	validation_0-logloss:0.49777
# [25]	validation_0-error:0.21645	validation_0-logloss:0.49947
# [0]	validation_0-error:0.24242	validation_0-logloss:0.54450
# [1]	validation_0-error:0.23810	validation_0-logloss:0.49769
# [2]	validation_0-error:0.24675	validation_0-logloss:0.49234
# [3]	validation_0-error:0.24675	validation_0-logloss:0.47784
# [4]	validation_0-error:0.22511	validation_0-logloss:0.46672
# [5]	validation_0-error:0.21212	validation_0-logloss:0.46760
# [6]	validation_0-error:0.22944	validation_0-logloss:0.46870
# [7]	validation_0-error:0.21645	validation_0-logloss:0.45834
# [8]	validation_0-error:0.20779	validation_0-logloss:0.45618
# [9]	validation_0-error:0.22078	validation_0-logloss:0.46375
# [10]	validation_0-error:0.24675	validation_0-logloss:0.47054
# [11]	validation_0-error:0.23810	validation_0-logloss:0.46107
# [12]	validation_0-error:0.21645	validation_0-logloss:0.47745
# [13]	validation_0-error:0.21645	validation_0-logloss:0.47716
# [14]	validation_0-error:0.22511	validation_0-logloss:0.47448
# [15]	validation_0-error:0.21212	validation_0-logloss:0.48335
# [16]	validation_0-error:0.21212	validation_0-logloss:0.47903
# [17]	validation_0-error:0.21645	validation_0-logloss:0.48548
# [18]	validation_0-error:0.23377	validation_0-logloss:0.49315
# [19]	validation_0-error:0.23810	validation_0-logloss:0.49728
# [20]	validation_0-error:0.21212	validation_0-logloss:0.50841
# [21]	validation_0-error:0.23377	validation_0-logloss:0.52147
# [22]	validation_0-error:0.23377	validation_0-logloss:0.53065
# [23]	validation_0-error:0.23377	validation_0-logloss:0.53296
# [24]	validation_0-error:0.22078	validation_0-logloss:0.52904
# [0]	validation_0-error:0.29437	validation_0-logloss:0.57351
# [1]	validation_0-error:0.25974	validation_0-logloss:0.52667
# [2]	validation_0-error:0.24242	validation_0-logloss:0.50367
# [3]	validation_0-error:0.24675	validation_0-logloss:0.49403
# [4]	validation_0-error:0.24675	validation_0-logloss:0.49212
# [5]	validation_0-error:0.22944	validation_0-logloss:0.49034
# [6]	validation_0-error:0.22944	validation_0-logloss:0.49007
# [7]	validation_0-error:0.23810	validation_0-logloss:0.48062
# [8]	validation_0-error:0.21212	validation_0-logloss:0.48048
# [9]	validation_0-error:0.23377	validation_0-logloss:0.48199
# [10]	validation_0-error:0.22078	validation_0-logloss:0.49802
# [11]	validation_0-error:0.22511	validation_0-logloss:0.49612
# [12]	validation_0-error:0.22944	validation_0-logloss:0.51615
# [13]	validation_0-error:0.24675	validation_0-logloss:0.53221
# [14]	validation_0-error:0.24675	validation_0-logloss:0.52714
# [15]	validation_0-error:0.24242	validation_0-logloss:0.52429
# [16]	validation_0-error:0.23810	validation_0-logloss:0.52860
# [17]	validation_0-error:0.24675	validation_0-logloss:0.53946
# [18]	validation_0-error:0.24675	validation_0-logloss:0.53981
# [19]	validation_0-error:0.25541	validation_0-logloss:0.55265
# [20]	validation_0-error:0.24675	validation_0-logloss:0.55689
# [21]	validation_0-error:0.24675	validation_0-logloss:0.55074
# [22]	validation_0-error:0.25541	validation_0-logloss:0.55063
# [23]	validation_0-error:0.25541	validation_0-logloss:0.55536
# [24]	validation_0-error:0.23810	validation_0-logloss:0.56635
# [0]	validation_0-error:0.31169	validation_0-logloss:0.58118
# [1]	validation_0-error:0.27273	validation_0-logloss:0.53120
# [2]	validation_0-error:0.23810	validation_0-logloss:0.49164
# [3]	validation_0-error:0.24675	validation_0-logloss:0.46761
# [4]	validation_0-error:0.24242	validation_0-logloss:0.45413
# [5]	validation_0-error:0.22511	validation_0-logloss:0.45806
# [6]	validation_0-error:0.19481	validation_0-logloss:0.45385
# [7]	validation_0-error:0.20346	validation_0-logloss:0.46363
# [8]	validation_0-error:0.19913	validation_0-logloss:0.46366
# [9]	validation_0-error:0.19048	validation_0-logloss:0.45592
# [10]	validation_0-error:0.18615	validation_0-logloss:0.45499
# [11]	validation_0-error:0.20346	validation_0-logloss:0.46445
# [12]	validation_0-error:0.20779	validation_0-logloss:0.48015
# [13]	validation_0-error:0.20779	validation_0-logloss:0.47983
# [14]	validation_0-error:0.19913	validation_0-logloss:0.47410
# [15]	validation_0-error:0.21645	validation_0-logloss:0.48077
# [16]	validation_0-error:0.20779	validation_0-logloss:0.49757
# [17]	validation_0-error:0.20779	validation_0-logloss:0.49379
# [18]	validation_0-error:0.21645	validation_0-logloss:0.49696
# [19]	validation_0-error:0.22511	validation_0-logloss:0.49397
# [20]	validation_0-error:0.21645	validation_0-logloss:0.49566
# [21]	validation_0-error:0.22511	validation_0-logloss:0.50523
# [22]	validation_0-error:0.22944	validation_0-logloss:0.50959
# [23]	validation_0-error:0.24242	validation_0-logloss:0.51847
# [24]	validation_0-error:0.23377	validation_0-logloss:0.51588
# [0]	validation_0-error:0.27273	validation_0-logloss:0.55752
# [1]	validation_0-error:0.25108	validation_0-logloss:0.50663
# [2]	validation_0-error:0.21645	validation_0-logloss:0.48895
# [3]	validation_0-error:0.20779	validation_0-logloss:0.46063
# [4]	validation_0-error:0.19481	validation_0-logloss:0.44474
# [5]	validation_0-error:0.19481	validation_0-logloss:0.43667
# [6]	validation_0-error:0.18615	validation_0-logloss:0.43337
# [7]	validation_0-error:0.19913	validation_0-logloss:0.43934
# ...
# [13]	validation_0-error:0.22511	validation_0-logloss:0.45076
# [14]	validation_0-error:0.22944	validation_0-logloss:0.44968
# [15]	validation_0-error:0.21212	validation_0-logloss:0.44402
# [16]	validation_0-error:0.22078	validation_0-logloss:0.44268
# [17]	validation_0-error:0.20346	validation_0-logloss:0.44201
# [18]	validation_0-error:0.21212	validation_0-logloss:0.43993
# [19]	validation_0-error:0.22944	validation_0-logloss:0.44088
# [20]	validation_0-error:0.22944	validation_0-logloss:0.44390
# [21]	validation_0-error:0.21212	validation_0-logloss:0.44989
# [22]	validation_0-error:0.19048	validation_0-logloss:0.45504
# [23]	validation_0-error:0.19481	validation_0-logloss:0.45586
# [24]	validation_0-error:0.19913	validation_0-logloss:0.47213
# [25]	validation_0-error:0.21212	validation_0-logloss:0.46484
# [26]	validation_0-error:0.24242	validation_0-logloss:0.47706
# [27]	validation_0-error:0.22078	validation_0-logloss:0.48467
# [28]	validation_0-error:0.21645	validation_0-logloss:0.48219
# [29]	validation_0-error:0.23377	validation_0-logloss:0.48169
# [0]	validation_0-error:0.36797	validation_0-logloss:0.63557
# [1]	validation_0-error:0.36797	validation_0-logloss:0.61644
# [2]	validation_0-error:0.36797	validation_0-logloss:0.59520
# [3]	validation_0-error:0.29870	validation_0-logloss:0.57349
# [4]	validation_0-error:0.27273	validation_0-logloss:0.54780
# [5]	validation_0-error:0.24675	validation_0-logloss:0.53997
# [6]	validation_0-error:0.23810	validation_0-logloss:0.52861
# [7]	validation_0-error:0.23377	validation_0-logloss:0.52542
# [8]	validation_0-error:0.22078	validation_0-logloss:0.51363
# [9]	validation_0-error:0.21212	validation_0-logloss:0.50745
# [10]	validation_0-error:0.22078	validation_0-logloss:0.50219
# [11]	validation_0-error:0.21212	validation_0-logloss:0.49679
# [12]	validation_0-error:0.22078	validation_0-logloss:0.49064
# [13]	validation_0-error:0.22511	validation_0-logloss:0.49373
# [14]	validation_0-error:0.21645	validation_0-logloss:0.48872
# [15]	validation_0-error:0.22078	validation_0-logloss:0.48809
# [16]	validation_0-error:0.21212	validation_0-logloss:0.47797
# [17]	validation_0-error:0.20779	validation_0-logloss:0.47152
# [18]	validation_0-error:0.19913	validation_0-logloss:0.46700
# [19]	validation_0-error:0.19913	validation_0-logloss:0.46386
# [20]	validation_0-error:0.19481	validation_0-logloss:0.46462
# [21]	validation_0-error:0.18615	validation_0-logloss:0.46216
# [22]	validation_0-error:0.18182	validation_0-logloss:0.45838
# [23]	validation_0-error:0.19481	validation_0-logloss:0.45911
# [24]	validation_0-error:0.20346	validation_0-logloss:0.45641
# [25]	validation_0-error:0.20346	validation_0-logloss:0.45382
# [26]	validation_0-error:0.20346	validation_0-logloss:0.45618
# [27]	validation_0-error:0.19913	validation_0-logloss:0.45158
# [28]	validation_0-error:0.19481	validation_0-logloss:0.44525
# [29]	validation_0-error:0.19048	validation_0-logloss:0.44700
# [30]	validation_0-error:0.19481	validation_0-logloss:0.44734
# [31]	validation_0-error:0.19481	validation_0-logloss:0.44226
# [32]	validation_0-error:0.20779	validation_0-logloss:0.44371
# [33]	validation_0-error:0.19481	validation_0-logloss:0.44042
# [34]	validation_0-error:0.19481	validation_0-logloss:0.43968
# [35]	validation_0-error:0.19913	validation_0-logloss:0.44186
# [36]	validation_0-error:0.20346	validation_0-logloss:0.44423
# [37]	validation_0-error:0.20346	validation_0-logloss:0.44647
# [38]	validation_0-error:0.20346	validation_0-logloss:0.44104
# [39]	validation_0-error:0.19481	validation_0-logloss:0.44196
# Exception ignored on calling ctypes callback function: <bound method DataIter._next_wrapper of <xgboost.data.SingleBatchInternalIter object at 0x79c68933e290>>
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/xgboost/core.py", line 582, in _next_wrapper
#     def _next_wrapper(self, this: None) -> int:  # pylint: disable=unused-argument
# KeyboardInterrupt:
# [0]	validation_0-error:0.36797	validation_0-logloss:0.63473
# [1]	validation_0-error:0.36797	validation_0-logloss:0.61310
# [2]	validation_0-error:0.36797	validation_0-logloss:0.58748
# [3]	validation_0-error:0.33333	validation_0-logloss:0.56854
# [4]	validation_0-error:0.28139	validation_0-logloss:0.54867
# [5]	validation_0-error:0.26840	validation_0-logloss:0.53441
# [6]	validation_0-error:0.24675	validation_0-logloss:0.52347
# [7]	validation_0-error:0.25541	validation_0-logloss:0.51276
# [8]	validation_0-error:0.24242	validation_0-logloss:0.50846
# [9]	validation_0-error:0.23377	validation_0-logloss:0.49920
# [10]	validation_0-error:0.22511	validation_0-logloss:0.49161
# [11]	validation_0-error:0.20779	validation_0-logloss:0.48120
# [12]	validation_0-error:0.22078	validation_0-logloss:0.47947
# [13]	validation_0-error:0.21212	validation_0-logloss:0.47315
# [14]	validation_0-error:0.22078	validation_0-logloss:0.47032
# [15]	validation_0-error:0.19913	validation_0-logloss:0.46486
# [16]	validation_0-error:0.20779	validation_0-logloss:0.46313
# [17]	validation_0-error:0.22078	validation_0-logloss:0.46227
# [18]	validation_0-error:0.21212	validation_0-logloss:0.45632
# [19]	validation_0-error:0.20779	validation_0-logloss:0.44972
# [20]	validation_0-error:0.19913	validation_0-logloss:0.44640
# [21]	validation_0-error:0.20346	validation_0-logloss:0.44599
# [22]	validation_0-error:0.20346	validation_0-logloss:0.44658
# [23]	validation_0-error:0.20346	validation_0-logloss:0.44244
# [24]	validation_0-error:0.20346	validation_0-logloss:0.43945
# [25]	validation_0-error:0.20346	validation_0-logloss:0.43649
# [26]	validation_0-error:0.19913	validation_0-logloss:0.43543
# [27]	validation_0-error:0.20779	validation_0-logloss:0.43460
# [28]	validation_0-error:0.21212	validation_0-logloss:0.43569
# [29]	validation_0-error:0.20346	validation_0-logloss:0.43032
# [30]	validation_0-error:0.20346	validation_0-logloss:0.43095
# [31]	validation_0-error:0.20346	validation_0-logloss:0.43338
# [32]	validation_0-error:0.20779	validation_0-logloss:0.43425
# [33]	validation_0-error:0.21212	validation_0-logloss:0.43412
# [34]	validation_0-error:0.21645	validation_0-logloss:0.43209
# [35]	validation_0-error:0.21645	validation_0-logloss:0.43273
# [36]	validation_0-error:0.21645	validation_0-logloss:0.43122
# [37]	validation_0-error:0.22078	validation_0-logloss:0.43080
# [38]	validation_0-error:0.21645	validation_0-logloss:0.42740
# [39]	validation_0-error:0.21212	validation_0-logloss:0.42893
# [0]	validation_0-error:0.36797	validation_0-logloss:0.63029
# [1]	validation_0-error:0.36797	validation_0-logloss:0.60294
# [2]	validation_0-error:0.36797	validation_0-logloss:0.58666
# [3]	validation_0-error:0.31169	validation_0-logloss:0.56772
# [4]	validation_0-error:0.26840	validation_0-logloss:0.54794
# [5]	validation_0-error:0.25108	validation_0-logloss:0.53919
# [6]	validation_0-error:0.24242	validation_0-logloss:0.53243
# [7]	validation_0-error:0.22944	validation_0-logloss:0.52157
# [8]	validation_0-error:0.21212	validation_0-logloss:0.51171
# [9]	validation_0-error:0.21212	validation_0-logloss:0.50242
# [10]	validation_0-error:0.20346	validation_0-logloss:0.49374
# [11]	validation_0-error:0.21645	validation_0-logloss:0.48372
# [12]	validation_0-error:0.21212	validation_0-logloss:0.47899
# [13]	validation_0-error:0.21645	validation_0-logloss:0.47715
# [14]	validation_0-error:0.22078	validation_0-logloss:0.47311
# [15]	validation_0-error:0.21645	validation_0-logloss:0.46647
# [16]	validation_0-error:0.21212	validation_0-logloss:0.46288
# [17]	validation_0-error:0.22078	validation_0-logloss:0.46041
# [18]	validation_0-error:0.21212	validation_0-logloss:0.45886
# [19]	validation_0-error:0.20779	validation_0-logloss:0.45397
# [20]	validation_0-error:0.21645	validation_0-logloss:0.45565
# [21]	validation_0-error:0.21212	validation_0-logloss:0.45657
# [22]	validation_0-error:0.21212	validation_0-logloss:0.45710
# [23]	validation_0-error:0.21212	validation_0-logloss:0.45301
# [24]	validation_0-error:0.21212	validation_0-logloss:0.45236
# [25]	validation_0-error:0.21212	validation_0-logloss:0.45386
# [26]	validation_0-error:0.20346	validation_0-logloss:0.45360
# [27]	validation_0-error:0.20779	validation_0-logloss:0.45430
# [28]	validation_0-error:0.21212	validation_0-logloss:0.45464
# [29]	validation_0-error:0.21645	validation_0-logloss:0.45032
# [30]	validation_0-error:0.20346	validation_0-logloss:0.45156
# [31]	validation_0-error:0.20346	validation_0-logloss:0.45227
# [32]	validation_0-error:0.20779	validation_0-logloss:0.45087
# [33]	validation_0-error:0.19913	validation_0-logloss:0.44777
# [34]	validation_0-error:0.20346	validation_0-logloss:0.44771
# [35]	validation_0-error:0.19913	validation_0-logloss:0.44595
# [36]	validation_0-error:0.19913	validation_0-logloss:0.44268
# [37]	validation_0-error:0.19481	validation_0-logloss:0.44058
# [38]	validation_0-error:0.20779	validation_0-logloss:0.43743
# [39]	validation_0-error:0.20346	validation_0-logloss:0.43686
# [0]	validation_0-error:0.36797	validation_0-logloss:0.62835
# [1]	validation_0-error:0.36797	validation_0-logloss:0.60549
# [2]	validation_0-error:0.36797	validation_0-logloss:0.59214
# [3]	validation_0-error:0.32900	validation_0-logloss:0.57318
# [4]	validation_0-error:0.28571	validation_0-logloss:0.55669
# [5]	validation_0-error:0.24675	validation_0-logloss:0.54395
# [6]	validation_0-error:0.25108	validation_0-logloss:0.52935
# [7]	validation_0-error:0.23810	validation_0-logloss:0.52082
# [8]	validation_0-error:0.22511	validation_0-logloss:0.51116
# [9]	validation_0-error:0.22944	validation_0-logloss:0.50552
# [10]	validation_0-error:0.24242	validation_0-logloss:0.50242
# [11]	validation_0-error:0.22511	validation_0-logloss:0.49145
# [12]	validation_0-error:0.23377	validation_0-logloss:0.48565
# [13]	validation_0-error:0.23377	validation_0-logloss:0.47682
# [14]	validation_0-error:0.21212	validation_0-logloss:0.47116
# [15]	validation_0-error:0.19913	validation_0-logloss:0.46116
# [16]	validation_0-error:0.20346	validation_0-logloss:0.45566
# [17]	validation_0-error:0.20779	validation_0-logloss:0.45391
# [18]	validation_0-error:0.20346	validation_0-logloss:0.45130
# [19]	validation_0-error:0.20346	validation_0-logloss:0.45221
# [20]	validation_0-error:0.20346	validation_0-logloss:0.44797
# [21]	validation_0-error:0.21212	validation_0-logloss:0.45080
# [22]	validation_0-error:0.20779	validation_0-logloss:0.44810
# [23]	validation_0-error:0.21212	validation_0-logloss:0.44608
# [24]	validation_0-error:0.20779	validation_0-logloss:0.44817
# [25]	validation_0-error:0.21212	validation_0-logloss:0.44728
# [26]	validation_0-error:0.20346	validation_0-logloss:0.45013
# [27]	validation_0-error:0.20346	validation_0-logloss:0.45055
# [28]	validation_0-error:0.20779	validation_0-logloss:0.44913
# [29]	validation_0-error:0.21212	validation_0-logloss:0.44660
# [30]	validation_0-error:0.21212	validation_0-logloss:0.44748
# [31]	validation_0-error:0.21212	validation_0-logloss:0.44614
# [32]	validation_0-error:0.21212	validation_0-logloss:0.44188
# [33]	validation_0-error:0.21645	validation_0-logloss:0.44252
# [34]	validation_0-error:0.21212	validation_0-logloss:0.44197
# [35]	validation_0-error:0.21645	validation_0-logloss:0.44318
# [36]	validation_0-error:0.21212	validation_0-logloss:0.44148
# [37]	validation_0-error:0.21645	validation_0-logloss:0.44157
# [38]	validation_0-error:0.21645	validation_0-logloss:0.44419
# [39]	validation_0-error:0.21212	validation_0-logloss:0.44653
# [0]	validation_0-error:0.36797	validation_0-logloss:0.59378
# [1]	validation_0-error:0.25541	validation_0-logloss:0.55040
# [2]	validation_0-error:0.23377	validation_0-logloss:0.51665
# [3]	validation_0-error:0.21212	validation_0-logloss:0.48762
# [4]	validation_0-error:0.21212	validation_0-logloss:0.47379
# [5]	validation_0-error:0.20346	validation_0-logloss:0.46111
# [6]	validation_0-error:0.20779	validation_0-logloss:0.45867
# [7]	validation_0-error:0.20346	validation_0-logloss:0.46207
# [8]	validation_0-error:0.20779	validation_0-logloss:0.45403
# [9]	validation_0-error:0.19913	validation_0-logloss:0.45708
# [10]	validation_0-error:0.21645	validation_0-logloss:0.45961
# [11]	validation_0-error:0.19913	validation_0-logloss:0.46427
# [12]	validation_0-error:0.21645	validation_0-logloss:0.46483
# [13]	validation_0-error:0.22511	validation_0-logloss:0.45907
# [14]	validation_0-error:0.23377	validation_0-logloss:0.46652
# [15]	validation_0-error:0.22944	validation_0-logloss:0.46970
# [16]	validation_0-error:0.22078	validation_0-logloss:0.48217
# [17]	validation_0-error:0.22944	validation_0-logloss:0.48538
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:540: FitFailedWarning:
# 1 fits failed out of a total of 50.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 1 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py", line 1512, in fit
#     train_dmatrix, evals = _wrap_evaluation_matrices(
#   File "/usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py", line 647, in _wrap_evaluation_matrices
#     m = create_dmatrix(
#   File "/usr/local/lib/python3.10/dist-packages/xgboost/sklearn.py", line 1003, in _create_dmatrix
#     return QuantileDMatrix(
#   File "/usr/local/lib/python3.10/dist-packages/xgboost/core.py", line 726, in inner_f
#     return func(**kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/xgboost/core.py", line 1573, in __init__
#     self._init(
#   File "/usr/local/lib/python3.10/dist-packages/xgboost/core.py", line 1634, in _init
#     _check_call(ret)
#   File "/usr/local/lib/python3.10/dist-packages/xgboost/core.py", line 284, in _check_call
#     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
# xgboost.core.XGBoostError: [05:05:35] /workspace/src/data/iterative_dmatrix.cc:263: Check failed: rbegin == Info().num_row_ (231 vs. 462) :
# Stack trace:
#   [bt] (0) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x22dcbc) [0x79c67b62dcbc]
#   [bt] (1) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x51ba96) [0x79c67b91ba96]
#   [bt] (2) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x51dbbc) [0x79c67b91dbbc]
#   [bt] (3) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(+0x4cd1ca) [0x79c67b8cd1ca]
#   [bt] (4) /usr/local/lib/python3.10/dist-packages/xgboost/lib/libxgboost.so(XGQuantileDMatrixCreateFromCallback+0x18c) [0x79c67b54556c]
#   [bt] (5) /lib/x86_64-linux-gnu/libffi.so.8(+0x7e2e) [0x79c6e4bf2e2e]
#   [bt] (6) /lib/x86_64-linux-gnu/libffi.so.8(+0x4493) [0x79c6e4bef493]
#   [bt] (7) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0xa3e9) [0x79c6e4c183e9]
#   [bt] (8) /usr/lib/python3.10/lib-dynload/_ctypes.cpython-310-x86_64-linux-gnu.so(+0x9a00) [0x79c6e4c17a00]
#
#
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:1103: UserWarning: One or more of the test scores are non-finite: [0.75794393 0.72076843 0.76363794 0.75055382 0.74312911 0.75057113
#  0.75430945 0.73186224 0.72260298        nan]
#   warnings.warn(
# [18]	validation_0-error:0.24675	validation_0-logloss:0.49217
# [19]	validation_0-error:0.23377	validation_0-logloss:0.50032
# [20]	validation_0-error:0.23810	validation_0-logloss:0.49865
# [21]	validation_0-error:0.24242	validation_0-logloss:0.50168
# [22]	validation_0-error:0.24675	validation_0-logloss:0.50621
# [23]	validation_0-error:0.25108	validation_0-logloss:0.50786
# [24]	validation_0-error:0.25974	validation_0-logloss:0.50153
# [25]	validation_0-error:0.25541	validation_0-logloss:0.50239
# [26]	validation_0-error:0.26407	validation_0-logloss:0.50830
# [27]	validation_0-error:0.26407	validation_0-logloss:0.51661
# test_score - 0.7922077922077922

# %%
print(random_search.best_params_)
# Out:
# {'subsample': 0.5, 'n_estimators': 40, 'max_depth': 12, 'learning_rate': 0.25}

# %%
import xgboost as xgb
from sklearn.metrics import classification_report,confusion_matrix, accuracy_score

model = xgb.XGBClassifier(max_depth=12,
                        subsample=0.2,
                        objective='binary:logistic',
                        n_estimators=40,
                        learning_rate = 0.1,
                        early_stopping_rounds=15,
                        eval_metric=["error", "logloss"])
eval_set = [(X_train, y_train), (X_test, y_test)]
model.fit(X_train, y_train.values.ravel(), eval_set=eval_set, verbose=False)
y_pred=model.predict(X_test)
print("train_score - " + str(model .score(X_train, y_train)))
print("test_score - " + str(model .score(X_test, y_test)))
# Out:
# train_score - 0.8379888268156425
# test_score - 0.7878787878787878

# %%
from sklearn.metrics import f1_score, accuracy_score, precision_score, recall_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
cm=confusion_matrix(y_test,y_pred)
print(cm)
f1 = f1_score(y_test, y_pred)
accuracy = accuracy_score(y_test, y_pred)
precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# Print the metrics
print("F1 Score: ", np.round(f1,3))
print("Accuracy: ", np.round(accuracy,3))
print("Precision:", np.round(precision,3))
print("Recall:   ", np.round(recall,3))
tree_auc = roc_auc_score(y_test, model.predict_proba(X_test)[:,1])
print("ROC AUC:", np.round(tree_auc,3))
# Out:
# [[127  19]
#  [ 30  55]]
# F1 Score:  0.692
# Accuracy:  0.788
# Precision: 0.743
# Recall:    0.647
# ROC AUC: 0.87

# %% [markdown]
# ##Model Evaluation

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

#  dt2, rf1, abc, and model are your respective models

tree_fpr, tree_tpr, _ = roc_curve(y_test, dt2.predict_proba(X_test)[:, 1])
rf_fpr, rf_tpr, _ = roc_curve(y_test, rf1.predict_proba(X_test)[:, 1])
gb_fpr, gb_tpr, _ = roc_curve(y_test, abc.predict_proba(X_test)[:, 1])
xgb_fpr, xgb_tpr, _ = roc_curve(y_test, model.predict_proba(X_test)[:, 1])

tree_auc = auc(tree_fpr, tree_tpr)
rf_auc = auc(rf_fpr, rf_tpr)
gb_auc = auc(gb_fpr, gb_tpr)
xgb_auc = auc(xgb_fpr, xgb_tpr)

plt.plot(tree_fpr, tree_tpr, marker='.', color='C0', label=f'Model1: Decision tree (AUC = {tree_auc:.2f})')
plt.plot(rf_fpr, rf_tpr, marker='.', color='C1', label=f'Model2: Random Forest (AUC = {rf_auc:.2f})')
plt.plot(gb_fpr, gb_tpr, marker='.', color='C2', label=f'Model3: Ada Boost (AUC = {gb_auc:.2f})')
plt.plot(xgb_fpr, xgb_tpr, marker='.', color='C4', label=f'Model4: XG Boost (AUC = {xgb_auc:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--', label='Random Guess')

plt.legend()
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.show()
